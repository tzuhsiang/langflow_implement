# %%
import os
import json
import requests

origin_data_folder="/home/thhuang/voc_data/cht_sales_demo/data"
processed_data_folder="/home/thhuang/myproject/langflow_implement/processed_json"

langflow_api="http://localhost:7860/api/v1/run/75239f90-969d-4452-b3ce-b256cce9ba2d?stream=false"
# langflow_api="http://localhost:7860/api/v1/run/3609db05-62d9-4cec-8dd6-5f9a2fdde803?stream=false"

# %%
#讀取origin_data_folder的json檔案
def read_json_files(folder_path):
    json_data = []
    for filename in os.listdir(folder_path):
        if filename.endswith('.json'):
            file_path = os.path.join(folder_path, filename)
            with open(file_path, 'r') as file:
                data = json.load(file)
                json_data.append(data)
    return json_data

#將json檔案寫入processed_data_folder
def write_json_files(folder_path, json_data):
    for i, data in enumerate(json_data):
        file_path = os.path.join(folder_path, f'processed_{i}.json')
        with open(file_path, 'w') as file:
            json.dump(data, file, indent=4,ensure_ascii=False)

# %%
data_list=read_json_files(origin_data_folder)

# %%
# i=data_list[0]
# text=[]
# for sentence in i["conversations"]:
#     if sentence["type"]=="agent":
#         text.append(f"agent: {sentence["content"]}")
#     elif sentence["type"]=="customer":
#         text.append(f"customer: {sentence["content"]}")
# print(text)

# %%
# headers = {"Content-Type": "application/json"}
# data={"input_value": json.dumps(text)}
# response=requests.post(langflow_api, headers=headers, json=data)
# content=response.json()['outputs'][0]['outputs'][0]['results']['text']["text"]

# %%
# summary=[]
# # summary.append(f"customer: {json.loads(content)["customer"]}")
# summary.append(f"agent: {json.loads(content)["agent"]}")
# print(summary)

# %%
# 準備 API 請求
headers = {"Content-Type": "application/json"}

result_list=[]

total_dialogues=len(data_list)
dialogues_counter=1


for i in data_list[1090:total_dialogues]:
    
    counter=1

    total_sentences=len(i["conversations"])
    # processed_conversations=[]
    for sentence in i["conversations"]:
        text=[]
        for sentence in i["conversations"]:
            if sentence["type"]=="agent":
                text.append(f"agent: {sentence["content"]}")
            elif sentence["type"]=="customer":
                text.append(f"customer: {sentence["content"]}")
        # print(text)
        data={"input_value": json.dumps(text)}

    try:
        response=requests.post(langflow_api, headers=headers, json=data)
        content=response.json()['outputs'][0]['outputs'][0]['results']['text']["text"]

        summary=[]
        # summary.append(f"customer: {json.loads(content)["customer"]}")
        summary.append(f"agent: {json.loads(content)["agent"]}")
        # print(summary)
        
        i["summary"]=summary
        print(f"對話處理進度：{dialogues_counter}/{total_dialogues}, 完成ID:{i['contactid']}")
    except:
        print("Error in response:", response.text)
    

    result_list.append(i)

    file_path = os.path.join(processed_data_folder, f'processed_{i["contactid"]}.json')
    with open(file_path, 'w') as file:
        json.dump(i, file, indent=4,ensure_ascii=False)


    dialogues_counter+=1
# Out:
# 對話處理進度：1/1555, 完成ID:10000827
# 對話處理進度：2/1555, 完成ID:10000262
# 對話處理進度：3/1555, 完成ID:10000221
# 對話處理進度：4/1555, 完成ID:ZHO067G955
# 對話處理進度：5/1555, 完成ID:10001387
# 對話處理進度：6/1555, 完成ID:10001269
# 對話處理進度：7/1555, 完成ID:10000627
# 對話處理進度：8/1555, 完成ID:10000324
# 對話處理進度：9/1555, 完成ID:10000707
# 對話處理進度：10/1555, 完成ID:10000645
# 對話處理進度：11/1555, 完成ID:10000964
# 對話處理進度：12/1555, 完成ID:10000086
# 對話處理進度：76/1555, 完成ID:10000097
# 對話處理進度：77/1555, 完成ID:10000007
# 對話處理進度：78/1555, 完成ID:10000493
# 對話處理進度：79/1555, 完成ID:10001280
# 對話處理進度：80/1555, 完成ID:10000295
# 對話處理進度：81/1555, 完成ID:10000377
# 對話處理進度：82/1555, 完成ID:10000852
# 對話處理進度：83/1555, 完成ID:10000148
# 對話處理進度：84/1555, 完成ID:10001332
# 對話處理進度：85/1555, 完成ID:10001225
# 對話處理進度：86/1555, 完成ID:10001360
# 對話處理進度：87/1555, 完成ID:10000175
# 對話處理進度：88/1555, 完成ID:10001421
# 對話處理進度：89/1555, 完成ID:10000154
# 對話處理進度：90/1555, 完成ID:10000525
# 對話處理進度：91/1555, 完成ID:10001102
# 對話處理進度：92/1555, 完成ID:10000181
# 對話處理進度：93/1555, 完成ID:10001144
# 對話處理進度：94/1555, 完成ID:10001079
# 對話處理進度：95/1555, 完成ID:10001188
# 對話處理進度：96/1555, 完成ID:10000011
# 對話處理進度：97/1555, 完成ID:10001398
# 對話處理進度：98/1555, 完成ID:10001166
# 對話處理進度：99/1555, 完成ID:10000656
# 對話處理進度：100/1555, 完成ID:10001283
# 對話處理進度：101/1555, 完成ID:10001073
# 對話處理進度：102/1555, 完成ID:10000057
# 對話處理進度：103/1555, 完成ID:10001404
# 對話處理進度：104/1555, 完成ID:10000338
# 對話處理進度：105/1555, 完成ID:10001363
# 對話處理進度：106/1555, 完成ID:10000944
# 對話處理進度：107/1555, 完成ID:10001336
# 對話處理進度：108/1555, 完成ID:10000373
# 對話處理進度：109/1555, 完成ID:10001362
# Error in response: {"session_id":"75239f90-969d-4452-b3ce-b256cce9ba2d","outputs":[{"inputs":{"input_value":"[\"customer: \\u55e8\\uff0c\\u6211\\u6700\\u8fd1\\u5728\\u4f7f\\u7528\\u56fa\\u7db2\\u4e0a\\u7db2\\u6642\\u7d93\\u5e38\\u65b7\\u7dda\\uff0c\\u600e\\u9ebc\\u8fa6\\uff1f\", \"agent: \\u60a8\\u597d\\uff0c\\u5f88\\u62b1\\u6b49\\u807d\\u5230\\u60a8\\u9047\\u5230\\u65b7\\u7dda\\u7684\\u554f\\u984c\\u3002\\u6211\\u5011\\u53ef\\u4ee5\\u5148\\u6aa2\\u67e5\\u4e00\\u4e0b\\u60a8\\u7684\\u7db2\\u8def\\u8a2d\\u5099\\u662f\\u5426\\u6b63\\u5e38\\u904b\\u4f5c\\uff0c\\u4f8b\\u5982\\u8def\\u7531\\u5668\\u662f\\u5426\\u6709\\u7570\\u5e38\\u3002\", \"customer: \\u6211\\u525b\\u6aa2\\u67e5\\u904e\\u8def\\u7531\\u5668\\uff0c\\u6c92\\u6709\\u7570\\u5e38\\uff0c\\u4f46\\u65b7\\u7dda\\u554f\\u984c\\u9084\\u662f\\u6301\\u7e8c\\u767c\\u751f\\u3002\", \"agent: \\u90a3\\u53ef\\u80fd\\u662f\\u5176\\u4ed6\\u56e0\\u7d20\\u9020\\u6210\\u7684\\u65b7\\u7dda\\u554f\\u984c\\u
# 對話處理進度：390/1555, 完成ID:10000505
# 對話處理進度：391/1555, 完成ID:10001178
# 對話處理進度：392/1555, 完成ID:10001391
# 對話處理進度：393/1555, 完成ID:10001074
# 對話處理進度：394/1555, 完成ID:10000080
# 對話處理進度：395/1555, 完成ID:10000509
# 對話處理進度：396/1555, 完成ID:10001006
# 對話處理進度：397/1555, 完成ID:10001338
# 對話處理進度：398/1555, 完成ID:10000068
# 對話處理進度：399/1555, 完成ID:10000903
# 對話處理進度：400/1555, 完成ID:10001195
# 對話處理進度：401/1555, 完成ID:10001550
# 對話處理進度：402/1555, 完成ID:10001039
# 對話處理進度：403/1555, 完成ID:10000264
# 對話處理進度：404/1555, 完成ID:10000189
# 對話處理進度：405/1555, 完成ID:FGCLRKVD04
# 對話處理進度：406/1555, 完成ID:10000437
# 對話處理進度：407/1555, 完成ID:10001417
# Error in response: {"session_id":"75239f90-969d-4452-b3ce-b256cce9ba2d","outputs":[{"inputs":{"input_value":"[\"agent: \\u5582\\uff0c\\u60a8\\u597d\\uff0c\\u8acb\\u554f\\u662f\\u674e\\u5148\\u751f\\u55ce\\uff1f\", \"customer: \\u662f\\u7684\\uff0c\\u8acb\\u554f\\u54ea\\u4f4d\\uff1f\", \"agent: \\u674e\\u5148\\u751f\\u60a8\\u597d\\uff0c\\u6211\\u662f\\u4e2d\\u83ef\\u96fb\\u4fe1\\u7684\\u738b\\u5c0f\\u660e\\u3002\\u611f\\u8b1d\\u60a8\\u4e00\\u76f4\\u4ee5\\u4f86\\u4f7f\\u7528\\u6211\\u5011\\u7684100M\\u7db2\\u8def\\u670d\\u52d9\\u3002\\u73fe\\u5728\\u6211\\u5011\\u6709\\u4e00\\u500b\\u512a\\u60e0\\u6d3b\\u52d5\\uff0c\\u5c07\\u60a8\\u7684\\u7db2\\u8def\\u5347\\u7d1a\\u52301G/1G\\u5c0d\\u7a31\\u901f\\u7387\\uff0c\\u6708\\u8cbb\\u53ea\\u97001,299\\u5143\\u3002\", \"customer: \\u5347\\u7d1a\\u5f8c\\u7684\\u8cbb\\u7528\\u6bd4\\u6211\\u73fe\\u5728\\u9ad8\\u55ce\\uff1f\", \"agent: \\u5347\\u7d1a\\u5f8c\\u6bcf\\u6708\\u53ea\\u9700\\u591a\\u4ed8450\\u5143\\uff0c\\u800c\\u4e14\\u6211\\u5011\\u9084\\u6703\\u8d08\\u9001\\u60a81200\\u5143\\u7684\\u5168\\u806f\\u79ae\\u5238\\u548c1200\\u5143\\u7684\\u73fe\\u91d1\\u9ede\\u6578\\uff0c\\u53ef\\u4ee5\\u7528\\u4f86\\u6263\\u62b5\\u5e33\\u55ae\\u8cbb\\u7528\\u3002\\u9019\\u6a23\\u63db\\u7b97\\u8d77\\u4f86\\u5176\\u5be6\\u5f88\\u5212\\u7b97\\u3002\", \"customer: \\u807d\\u8d77\\u4f86\\u4e0d\\u932f\\uff0c\\u90a3\\u9700\\u8981\\u6211\\u505a\\u4ec0\\u9ebc\\u55ce\\uff1f\", \"agent: \\u60a8\\u53ea\\u9700\\u8981\\u5728\\u6536\\u5230\\u6211\\u5011\\u5de5\\u7a0b\\u5e2b\\u7684\\u7c21\\u8a0a\\u5f8c\\uff0c\\u628a\\u5bb6\\u88e1\\u7684MoD\\u95dc\\u6389\\u91cd\\u958b\\u5c31\\u53ef\\u4ee5\\u4e86\\uff0c\\u4e0d\\u9700\\u8981\\u6709\\u4eba\\u5728\\u5bb6\\u7b49\\u3002\\u9019\\u6a23\\u5c31\\u53ef\\u4ee5\\u5b8c\\u6210\\u5347\\u7d1a\\u3002\", \"customer: \\u597d\\u7684\\uff0c\\u90a3\\u5c31\\u5e6b\\u6211\\u8fa6\\u7406\\u5347\\u7d1a\\u5427\\u3002\", \"agent: \\u597d\\u7684\\uff0c\\u7a0d\\u5f8c\\u6703\\u6709\\u5c08\\u54e1\\u8207\\u60a8\\u806f\\u7d61\\u5b89\\u6392\\u88dd\\u6a5f\\u6642\\u9593\\u3002\\u795d\\u60a8\\u6709\\u7f8e\\u597d\\u7684\\u4e00\\u5929\\uff0c\\u518d\\u898b\\u3002\"]"},"outputs":[{"results":{"text":{"text_key":"text","data":{"text":"{\"agent\":\"客服向民眾介紹中華電信的網路升級優惠方案，將現有的100M網路升級為1G對稱速度，每月僅需增加450元，並贈送總價值2400元的禮券和現金點數。民眾詢問升級費用後，表示對方案有興趣並決定升級。客服告知民眾操作步驟，並安排專員聯絡安裝時間，最後祝福民眾。」","files":[],"timestamp":"2025-05-27 08:20:20 UTC","flow_id":"75239f90-969d-4452-b3ce-b256cce9ba2d"},"default_value":"","text":"{\"agent\":\"客服向民眾介紹中華電信的網路升級優惠方案，將現有的100M網路升級為1G對稱速度，每月僅需增加450元，並贈送總價值2400元的禮券和現金點數。民眾詢問升級費用後，表示對方案有興趣並決定升級。客服告知民眾操作步驟，並安排專員聯絡安裝時間，最後祝福民眾。」","sender":null,"sender_name":null,"files":[],"session_id":"","timestamp":"2025-05-27T08:20:20+00:00","flow_id":"75239f90-969d-4452-b3ce-b256cce9ba2d","error":false,"edit":false,"properties":{"text_color":null,"background_color":null,"edited":false,"source":{"id":null,"display_name":null,"source":null},"icon":null,"allow_markdown":false,"positive_feedback":null,"state":"complete","targets":[]},"category":"message","content_blocks":[]}},"artifacts":{"text":{"repr":"{\"agent\":\"客服向民眾介紹中華電信的網路升級優惠方案，將現有的100M網路升級為1G對稱速度，每月僅需增加450元，並贈送總價值2400元的禮券和現金點數。民眾詢問升級費用後，表示對方案有興趣並決定升級。客服告知民眾操作步驟，並安排專員聯絡安裝時間，最後祝福民眾。」","raw":"{\"agent\":\"客服向民眾介紹中華電信的網路升級優惠方案，將現有的100M網路升級為1G對稱速度，每月僅需增加450元，並贈送總價值2400元的禮券和現金點數。民眾詢問升級費用後，表示對方案有興趣並決定升級。客服告知民眾操作步驟，並安排專員聯絡安裝時間，最後祝福民眾。」","type":"text"}},"outputs":{"text":{"message":"{\"agent\":\"客服向民眾介紹中華電信的網路升級優惠方案，將現有的100M網路升級為1G對稱速度，每月僅需增加450元，並贈送總價值2400元的禮券和現金點數。民眾詢問升級費用後，表示對方案有興趣並決定升級。客服告知民眾操作步驟，並安排專員聯絡安裝時間，最後祝福民眾。」","type":"text"}},"logs":{"text":[]},"messages":[{"message":"{\"agent\":\"客服向民眾介紹中華電信的網路升級優惠方案，將現有的100M網路升級為1G對稱速度，每月僅需增加450元，並贈送總價值2400元的禮券和現金點數。民眾詢問升級費用後，表示對方案有興趣並決定升級。客服告知民眾操作步驟，並安排專員聯絡安裝時間，最後祝福民眾。」","sender":"Machine","sender_name":"AI","session_id":"","stream_url":null,"component_id":"TextOutput-uHaJj","files":[],"type":"text"}],"timedelta":null,"duration":null,"component_display_name":"Text Output","component_id":"TextOutput-uHaJj","used_frozen_re ...
# 對話處理進度：409/1555, 完成ID:10001148
# 對話處理進度：410/1555, 完成ID:10001457
# 對話處理進度：411/1555, 完成ID:10000363
# 對話處理進度：412/1555, 完成ID:10000375
# 對話處理進度：413/1555, 完成ID:10000787
# 對話處理進度：414/1555, 完成ID:10001375
# 對話處理進度：415/1555, 完成ID:10001279
# 對話處理進度：416/1555, 完成ID:10001252
# 對話處理進度：417/1555, 完成ID:10000866
# 對話處理進度：418/1555, 完成ID:10000797
# 對話處理進度：419/1555, 完成ID:10000067
# 對話處理進度：420/1555, 完成ID:10000675
# 對話處理進度：421/1555, 完成ID:10001521
# 對話處理進度：422/1555, 完成ID:10001111
# 對話處理進度：423/1555, 完成ID:10000718
# 對話處理進度：424/1555, 完成ID:10001169
# 對話處理進度：425/1555, 完成ID:10000874
# 對話處理進度：426/1555, 完成ID:10000696
# 對話處理進度：427/1555, 完成ID:10001044
# 對話處理進度：428/1555, 完成ID:10000644
# 對話處理進度：429/1555, 完成ID:10000084
# 對話處理進度：430/1555, 完成ID:10000034
# 對話處理進度：431/1555, 完成ID:10000932
# 對話處理進度：432/1555, 完成ID:10000859
# 對話處理進度：433/1555, 完成ID:10000856
# 對話處理進度：434/1555, 完成ID:10000566
# 對話處理進度：435/1555, 完成ID:10001146
# 對話處理進度：436/1555, 完成ID:10001289
# 對話處理進度：437/1555, 完成ID:10000439
# 對話處理進度：438/1555, 完成ID:10000340
# 對話處理進度：439/1555, 完成ID:10001155
# 對話處理進度：440/1555, 完成ID:10000049
# 對話處理進度：441/1555, 完成ID:10000936
# 對話處理進度：442/1555, 完成ID:10000867
# 對話處理進度：443/1555, 完成ID:10000231
# 對話處理進度：444/1555, 完成ID:10000671
# 對話處理進度：445/1555, 完成ID:10000111
# 對話處理進度：446/1555, 完成ID:10001496
# 對話處理進度：447/1555, 完成ID:10000881
# 對話處理進度：448/1555, 完成ID:10001101
# 對話處理進度：449/1555, 完成ID:10000861
# 對話處理進度：450/1555, 完成ID:10001002
# 對話處理進度：451/1555, 完成ID:10000945
# 對話處理進度：452/1555, 完成ID:10001180
# 對話處理進度：453/1555, 完成ID:10000811
# 對話處理進度：454/1555, 完成ID:10000252
# 對話處理進度：455/1555, 完成ID:10001290
# 對話處理進度：456/1555, 完成ID:10001450
# 對話處理進度：457/1555, 完成ID:10000957
# 對話處理進度：458/1555, 完成ID:10001467
# 對話處理進度：459/1555, 完成ID:10001488
# 對話處理進度：460/1555, 完成ID:10000744
# 對話處理進度：461/1555, 完成ID:10000366
# 對話處理進度：462/1555, 完成ID:10000935
# 對話處理進度：463/1555, 完成ID:10000344
# 對話處理進度：464/1555, 完成ID:10000776
# 對話處理進度：465/1555, 完成ID:10000379

# %%
dialogues_counter
# Out:
# 466

# %%
len(result_list[dialogues_counter-11:dialogues_counter-1])
# Out:
# 10

# %%
#print(result_list[0]["summary"])
# Out:
# ['agent: 客戶經常遇到固網上網斷線問題，經過多次嘗試解決包括重啟路由器、重新設置網絡連接、更改Wi-Fi頻道及檢查設備設置等，仍無法解決問題。建議客戶聯繫技術支持團隊進行進一步排查與協助。', 'customer: 我的固網上網經常斷線，嘗試了重啟路由器、重新設置網絡連接、更改Wi-Fi頻道及檢查設備設置等方法，但問題依舊存在。希望能夠盡快解決這個問題，並在必要時聯繫技術支持團隊。']

# %%
write_json_files(processed_data_folder, result_list)

# %%
import requests

# 定義 API URL
# url = "http://10.144.84.72:7860"
url = "http://localhost:7860"

try:
    # 發送 GET 請求
    response = requests.get(url, timeout=5)
    
    # 檢查回應狀態碼
    if response.status_code == 200:
        print("成功連接到 API:", url)
    else:
        print(f"無法連接到 API，狀態碼: {response.status_code}")
except requests.exceptions.RequestException as e:
    print("連接失敗，錯誤訊息:", e)
# Out:
# 成功連接到 API: http://localhost:7860

# %%
import json

# 假設 fixed_content 是從 API 或其他來源獲得的
try:
    print("原始內容:", fixed_content)
    
    # 修正無效的轉義字符
    fixed_content = fixed_content.replace("\\", "\\\\")
    
    # 嘗試解析 JSON
    parsed_content = json.loads(fixed_content)
    print("解析後的內容:", parsed_content)
except json.JSONDecodeError as e:
    print("JSON 解碼失敗:", e)
# Out:
# 原始內容: [
#     {"type": "agent", "seq": "0", "content": "\\u6211\\u59d3[匿名處理]\\u54e1\\uff0c\\u7de8\\u865f[身份匿名處理]\\u5f88\\u9ad8\\u8208\\u70ba\\u60a8\\u670d\\u52d9\\u4f60\\u597d\\u3002", "starttime": "0.0", "endtime": "6.38"},
#     {"type": "customer", "seq": "1", "content": "\\u4f60\\u597d\\u655d\\u59d3[匿名處理]\\u8cb4\\u59d3\\u600e\\u9ebc\\u7a31\\u547c\\u4f60\\u662f[匿名處理]\\u5148\\u751f\\u60a8\\u597d\\uff0c\\u8acb\\u8aaa", "starttime": "3.38", "endtime": "10.62"},
#     {"type": "agent", "seq": "2", "content": "\\u6211\\u59d3[匿名處理]\\u3002", "starttime": "6.38", "endtime": "8.62"},
#     {"type": "agent", "seq": "3", "content": "\\u55ce\\uff1f\\u5e74\\u8fa6\\u6cd5\\u63a5\\u79d8\\u66f8\\u5ba4\\u7684\\u8aaa\\u660e\\u66f8[匿名處理]\\u5c0f\\u59d0\\u3002", "starttime": "9.88", "endtime": "17.75"},
#     {"type": "customer", "seq": "4", "content": "\\u[匿名處理]\\u5c0f\\u59d0\\u597d\\u5148\\u751f\\uff0c\\u60a8\\u7b49\\u4e00\\u4e0b\\u5594\\u6211\\u5e6b\\u4f60\\u78ba\\u8a8d\\u4e00\\u4e0b\\u5206\\u6a5f\\uff0c\\u8b1d\\u8b1d\\uff01", "starttime": "13.75", "endtime": "19.88"},
#     {"type": "agent", "seq": "5", "content": "\\u60a8\\u597d\\u6211\\u662f\\u5ba2\\u670d\\u4e2d\\u5fc3\\u5c08\\u54e1\\u7de8\\u865f[身份匿名處理]\\u5f88\\u9ad8\\u8208\\u70ba\\u60a8\\u670d\\u52d9\\u4f60\\u597d\\uff01", "starttime": "34.38", "endtime": "42.5"},
#     {"type": "customer", "seq": "6", "content": "\\u60a8\\u597d\\u662f\\u5df2\\u8ddf\\u4f60\\u78ba\\u5b9a\\u4e00\\u4e0b\\uff0c\\u6709\\u4e00\\u500b\\u4eba\\u8981\\u6c42\\u8981\\u6307\\u5b9a\\u8f49\\u66f8\\u79d8\\u66f8\\u5ba4[匿名處理]\\u5c0f\\u59d0\\u3002\\u6211\\u770b\\u4ed6\\u4eca\\u5929\\u524d\\u9762\\u6253\\u4e86\\u5169\\u901a\\u9032\\u4f86\\u4e86\\u632a\\uff0c\\u6211\\u8981\\u63a5\\u54ea\\u88e1\\u554a\\u3002", "starttime": "40.88", "endtime": "53.38"},
#     {"type": "agent", "seq": "7", "content": "\\u[匿名處理]\\u5c0f\\u59d0\\u5c31\\u662f\\u55c5\\u89ba\\u4e03\\u4e8c\\u516d\\u516d\\uff0c\\u5c0d\\u5c31\\u4e0d\\u8981\\u8b1b\\u5c31\\u9019\\u6bb5\\u4e00\\u4e8c\\u516d\\u516d\\u3002", "starttime": "48.5", "endtime": "60.0"},
#     {"type": "customer", "seq": "8", "content": "\\u4e00\\u4e8c\\u516d\\u516d\\u597d\\uff0c\\u8b1d\\u8b1d\\u5594\\u5594OK\\u597d\\u8b1d\\u8b1d\\uff01", "starttime": "54.88", "endtime": "59.75"},
#     {"type": "agent", "seq": "9", "content": "\\u5594", "starttime": "60.0", "endtime": "61.38"},
#     {"type": "agent", "seq": "10", "content": "\\u6216", "starttime": "64.88", "endtime": "67.5"},
#     {"type": "customer", "seq": "11", "content": "\\u55ef\\u8b1d\\u5c0f\\u59d0\\u4f60\\u597d\\uff0c\\u6211\\u662f\\u4ee5\\u4e0d\\u597d\\u610f\\u601d\\u7dda\\u4e0a\\u6709\\u500b[匿名處理]\\u5148\\u751f\\u8aaa\\uff0c\\u4ed6\\u8981\\u6307\\u5b9a\\u627e\\u60a8\\u6709\\u8ddf\\u4f60\\u901a\\u8a71\\u904e\\u90a3\\u80fd\\u5426\\uff0c\\u5148\\u50b3\\u7d66\\u60a8\\u502a\\u3002", "starttime": "65.75", "endtime": "75.88"},
#     {"type": "agent", "seq": "12", "content": "\\u597d\\u77e5\\u9053\\u4e86", "starttime": "75.62", "endtime": "77.88"},
#     {"type": "customer", "seq": "13", "content": "\\u597d\\uff0c\\u8b1d\\u8b1d\\uff01", "starttime": "76.25", "endtime": "79.0"},
#     {"type": "customer", "seq": "14", "content": "\\u60a8\\u597d\\u655d\\u59d3[匿名處理]\\u8acb\\u554f\\u600e\\u9ebc\\u7a31\\u547c\\u60a8\\uff01", "starttime": "78.88", "endtime": "83.0"},
#     {"type": "agent", "seq": "15", "content": "\\u6b38[匿名處理]\\u5c0f\\u59d0\\uff0c\\u4f60\\u597d\\uff0c[匿名處理]\\u5148\\u751f\\u8981\\u600e\\u6a23", "starttime": "82.62", "endtime": "87.38"},
#     {"type": "customer", "seq": "16", "content": "\\u6b38\\u5148\\u751f\\u60a8\\u597d\\u5443\\u60a8\\u662f\\u7db2\\u9801", "starttime": "84.12", "endtime": "90.0"},
#     {"type": "agent", "seq": "17", "content": "\\u563f\\uff01", "starttime": "87.75", "endtime": "89.12"},
#     {"type": "customer", "seq": "18", "content": "\\u90a3\\u6211\\u5148\\u751f\\u662f\\u4e0d\\u662f\\u662f\\u60a8\\u597d\\uff0c\\u90a3\\u60a8\\u7684\\u6848\\u5b50\\u6211\\u6709\\u65e9\\u4e0a\\u9084\\u770b\\u4e86\\u4e00\\u4e0b\\u6211\\u5011\\u4ee5\\u524d\\u6709\\u79fb\\u7d66\\u5c08\\u696d\\u91ab\\u5e2b\\u5be9\\u67e5\\u4e86\\u3002", "starttime": "90.0", "endtime": "102.0"},
#     {"type": "agent", "seq": "19", "content": "\\u5c0d\\u5c0d\\u5c0d\\u5c0d\\u5c0d\\u3002", "starttime": "90.62", "endtime": "93.0"},
#     {"type": "agent", "seq": "20", "content": "\\u563f\\u563f", "starttime": "97.62", "endtime": "99.25"},
#     {"type": "agent", "seq": "21", "content": "\\u6b38\\u4f60\\u5011\\u4e09\\u500b\\u79ae\\u62dc\\uff0c\\u4e0d\\u662f\\u5c31\\u5df2\\u7d93\\u79fb\\u9001\\u5c08\\u696d\\u91ab\\u5e2b\\u5be9\\u67e5\\u4e86\\u55ce\\uff1f", "starttime": "102.0", "endtime": "109.38"},
#     {"type": "customer", "seq": "22", "content": "\\u5c0d", "starttime": "102.75", "endtime": "104.5"},
#     {"type": "customer", "seq": "23", "content": "\\u6c92\\u6709\\u516b\\u6708\\u56db\\u865f\\u7684\\u6642\\u5019\\uff0c\\u6211\\u5011\\u4ee5\\u7d66\\u5c08\\u696d\\u91ab\\u5e2b\\u5be9\\u67e5\\u5e6b\\u4ed6\\u6708\\u56db\\u865f\\u5c0d\\u3002", "starttime": "107.88", "endtime": "117.5"},
#     {"type": "agent", "seq": "24", "content": "\\u516b\\u6708\\u56db\\u865f", "starttime": "114.5", "endtime": "116.62"},
#     {"type": "agent", "seq": "25", "content": "\\u554a\\uff0c\\u4eca\\u5929\\u5e7e\\u865f", "starttime": "117.62", "endtime": "120.0"},
#     {"type": "customer", "seq": "26", "content": "\\u5594\\u7b49\\u4e00\\u4e0b\\u4e0d\\u662f\\u516b\\u6708", "starttime": "117.88", "endtime": "120.0"},
#     {"type": "customer", "seq": "27", "content": "\\u56db\\u865f\\u7b49\\u6211\\u4e00\\u4e0b\\u6211\\u628a\\u4f60\\u7684\\u6a94\\u6848\\u8df3\\u51fa\\u4f86\\u56e0\\u70ba\\u6211\\u5728\\u770b\\u5225\\u7684\\u6771\\u897f\\u5c0d\\u4e0d\\u8d77\\u6211\\u770b\\u4e00\\u4e0b\\u3002", "starttime": "120.0", "endtime": "127.62"},
#     {"type": "customer", "seq": "28", "content": "\\u662f", "starttime": "127.75", "endtime": "129.88"},
#     {"type": "customer", "seq": "29", "content": "\\u5c0d\\u516b\\u6708\\u56db\\u865f\\u5df2\\u7d66\\u5c08\\u696d\\u91ab\\u5e2b\\uff0c\\u6211\\u770b\\u4ed6\\u90a3\\u500b\\u5c08\\u696d\\u91ab\\u5e2b\\u7684\\u90e8\\u5206\\u56de\\u4f86\\u4e86\\u6c92\\u6709\\u6211\\u9084\\u6c92\\u6709\\u3002", "starttime": "133.62", "endtime": "145.5"},
#     {"type": "agent", "seq": "30", "content": "\\u4e5d\\u865f\\u9700\\u8981\\u4e5f\\u4e5f\\u4eca\\u5929\\u75fe\\uff0c\\u4f60\\u8aaa\\u6700\\u6162\\u6642\\u9593\\u5462\\uff1f", "starttime": "142.75", "endtime": "150.0"},
#     {"type": "customer", "seq": "31", "content": "\\u6211\\u77e5\\u9053\\u61c9\\u8a72\\u662f\\u3002", "starttime": "147.25", "endtime": "150.0"},
#     {"type": "customer", "seq": "32", "content": "\\u8aaa\\u91ab\\u5e2b\\u7684\\u90e8\\u5206\\u6848\\u5b50\\u9084\\u6c92\\u6709\\u56de\\u4f86\\u7d66\\u6211\\u5011\\uff0c\\u90a3\\u60a8\\u7684\\u6848\\u5b50\\uff0c\\u6211\\u9084\\u662f\\u6703\\u7559\\u610f\\u5230\\u76ee\\u524d\\u70ba\\u6b62\\u91ab\\u5e2b\\u6211\\u5011\\u662f\\u516b\\u6708\\u56db\\u865f\\u9001\\u91ab\\u5e2b\\u5c08\\u696d\\u4e00\\u3002", "starttime": "150.0", "endtime": "164.15"},
#     {"type": "customer", "seq": "33", "content": "\\u9084\\u6c92\\u6709\\u56de\\u8986\\u7d66\\u52de\\u4fdd\\u5c40\\uff0c\\u90a3\\u5982\\u679c\\u4ed6\\u4e00\\u65e6\\u56de\\u8986\\u7d66\\u52de\\u4fdd\\u5c40\\uff0c\\u6211\\u5c31\\u99ac\\u4e0a\\u8acb\\u4ed6\\u5011\\u89e3\\u6848\\uff0c\\u5982\\u679c\\u6c92\\u6709\\u5176\\u4ed6\\u7591\\u7fa9\\uff0c\\u6211\\u5c31\\u8acb\\u4ed6\\u5011\\u59d0\\u5f88\\u597d\\u4e0d\\u597d\\u3002", "starttime": "165.25", "endtime": "177.12"},
#     {"type": "agent", "seq": "34", "content": "\\u9019\\u6a23\\u5594", "starttime": "176.75", "endtime": "178.62"},
#     {"type": "customer", "seq": "35", "content": "\\u662f\\u662f\\u662f", "starttime": "177.62", "endtime": "180.0"},
#     {"type": "agent", "seq": "36", "content": "\\u6b38\\uff01", "starttime": "178.5", "endtime": "180.0"},
#     {"type": "agent", "seq": "37", "content": "\\u518d\\u9ebb\\u7169\\u4f60\\u4e00\\u4e0b\\u751f\\u7684\\u8eab\\u5206\\u3002", "starttime": "180.0", "endtime": "183.25"},
#     {"type": "customer", "seq": "38", "content": "\\u6703\\u8ac7\\u9084\\u6709\\u6211\\u77e5\\u9053\\u6211\\u77e5\\u9053\\uff0c\\u56e0\\u70ba\\u6211\\u8981\\u5148\\u60a8\\u6709\\u63d0\\u5230\\u8aaa\\u5443\\uff0c\\u78ba\\u5be6\\u4ed6\\u9084\\u6709\\u554f\\u984c\\uff0c\\u6211\\u667a\\u5546\\u671f\\u9593\\u78ba\\u5be6\\u7e3d\\u662f\\u6703\\u6709\\u4e00\\u4e9b\\u7d93\\u6fdf\\u4e0a\\u7684\\u9700\\u8981\\u3002", "starttime": "180.25", "endtime": "194.75"},
#     {"type": "agent", "seq": "39", "content": "\\u5c0d", "starttime": "186.0", "endtime": "187.5"},
#     {"type": "agent", "seq": "40", "content": "\\u53ef\\u4ee5\\u554a\\uff01", "starttime": "194.25", "endtime": "196.75"},
#     {"type": "customer", "seq": "41", "content": "\\u90a3\\u6211\\u65e9\\u4e0a\\u6211\\u5c31\\u6709\\u518d\\u53bb\\u8ffd\\u8e64\\u4e00\\u4e0b\\u6848\\u5b50\\uff0c\\u53ef\\u662f\\u56e0\\u70ba\\u5443\\uff0c\\u4ed6\\u7684\\u91ab\\u5e2b\\u5be9\\u67e5\\u7684\\u90e8\\u5206\\u9084\\u6c92\\u6709\\u56de\\u4f86\\uff0c\\u6211\\u96d6\\u4ed6\\u5011\\u5c31\\u6c92\\u6709\\u7528\\uff0c\\u90a3\\u5fc5\\u9808\\u8981\\u7b49\\u
# JSON 解碼失敗: Unterminated string starting at: line 43 column 50 (char 10032)
