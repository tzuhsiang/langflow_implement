# %%
import os
import json
import requests

origin_data_folder="/home/thhuang/myproject/langflow_implement/processed_json"
processed_data_folder="/home/thhuang/myproject/langflow_implement/processed_json"

langflow_api="http://localhost:7860/api/v1/run/929d90d3-e00d-4c5a-bf45-ca37fec46b1e?stream=false"
# langflow_api="http://localhost:7860/api/v1/run/3609db05-62d9-4cec-8dd6-5f9a2fdde803?stream=false"

# %%
#讀取origin_data_folder的json檔案
def read_json_files(folder_path):
    json_data = []
    for filename in os.listdir(folder_path):
        if filename.endswith('.json'):
            file_path = os.path.join(folder_path, filename)
            with open(file_path, 'r') as file:
                data = json.load(file)
                json_data.append(data)
    return json_data

#將json檔案寫入processed_data_folder
def write_json_files(folder_path, json_data):
    for i, data in enumerate(json_data):
        file_path = os.path.join(folder_path, f'processed_{i}.json')
        with open(file_path, 'w') as file:
            json.dump(data, file, indent=4,ensure_ascii=False)

# %%
data_list=read_json_files(origin_data_folder)

# %%
# i=data_list[0]
# text=[]
# for sentence in i["conversations"]:
#     if sentence["type"]=="agent":
#         text.append(f"agent: {sentence["content"]}")
#     elif sentence["type"]=="customer":
#         text.append(f"customer: {sentence["content"]}")
# print(text)

# %%
# headers = {"Content-Type": "application/json"}
# data={"input_value": json.dumps(text)}
# response=requests.post(langflow_api, headers=headers, json=data)
# content=response.json()['outputs'][0]['outputs'][0]['results']['text']["text"]

# %%
# classes=[]
# # summary.append(f"customer: {json.loads(content)["customer"]}")
# if type(json.loads(content)) is list:
#     classes=json.loads(content)
# else:
#     classes.append("-")

# print(classes)

# %%
# 準備 API 請求
headers = {"Content-Type": "application/json"}

result_list=[]

total_dialogues=len(data_list)
dialogues_counter=1


for i in data_list:
    
    counter=1

    total_sentences=len(i["conversations"])
    # processed_conversations=[]
    for sentence in i["conversations"]:
        text=[]
        for sentence in i["conversations"]:
            if sentence["type"]=="agent":
                text.append(f"agent: {sentence["content"]}")
            elif sentence["type"]=="customer":
                text.append(f"customer: {sentence["content"]}")
        # print(text)
        data={"input_value": json.dumps(text)}

    try:
        response=requests.post(langflow_api, headers=headers, json=data)
        content=response.json()['outputs'][0]['outputs'][0]['results']['text']["text"]

        classes=[]
        if type(json.loads(content)) is list:
            classes=json.loads(content)
        else:
            classes.append("-")
        
        i["classes"]=classes
        print(f"對話處理進度：{dialogues_counter}/{total_dialogues}, 完成ID:{i['contactid']}")

    except:
        print("Error in response:", response.text)
    

    result_list.append(i)

    file_path = os.path.join(processed_data_folder, f'processed_{i["contactid"]}.json')
    with open(file_path, 'w') as file:
        json.dump(i, file, indent=4,ensure_ascii=False)


    dialogues_counter+=1
# Out:
# 對話處理進度：1/1091, 完成ID:10000241
# 對話處理進度：2/1091, 完成ID:10001112
# 對話處理進度：3/1091, 完成ID:10000946
# 對話處理進度：4/1091, 完成ID:10000098
# 對話處理進度：5/1091, 完成ID:10001105
# 對話處理進度：6/1091, 完成ID:10000243
# 對話處理進度：7/1091, 完成ID:10000459
# 對話處理進度：8/1091, 完成ID:10001493
# 對話處理進度：9/1091, 完成ID:10000126
# 對話處理進度：10/1091, 完成ID:10001529
# 對話處理進度：11/1091, 完成ID:10000165
# 對話處理進度：12/1091, 完成ID:10000598
# 對話處理進度：13/1091, 完成ID:10001303
# 對話處理進度：14/1091, 完成ID:10000642
# 對話處理進度：15/1091, 完成ID:10000725
# 對話處理進度：16/1091, 完成ID:10001547
# 對話處理進度：17/1091, 完成ID:10000064
# 對話處理進度：18/1091, 完成ID:10001472
# 對話處理進度：19/1091, 完成ID:10000300
# 對話處理進度：20/1091, 完成ID:10000024
# 對話處理進度：21/1091, 完成ID:10000546
# 對話處理進度：22/1091, 完成ID:10001468
# 對話處理進度：23/1091, 完成ID:10001386
# 對話處理進度：24/1091, 完成ID:10000282
# 對話處理進度：25/1091, 完成ID:10000923
# 對話處理進度：26/1091, 完成ID:10000450
# 對話處理進度：27/1091, 完成ID:10001514
# 對話處理進度：28/1091, 完成ID:10000135
# 對話處理進度：29/1091, 完成ID:10000357
# 對話處理進度：30/1091, 完成ID:10001216
# 對話處理進度：31/1091, 完成ID:10000246
# 對話處理進度：32/1091, 完成ID:10000976
# 對話處理進度：33/1091, 完成ID:10001287
# 對話處理進度：34/1091, 完成ID:10000694
# 對話處理進度：35/1091, 完成ID:10001501
# 對話處理進度：36/1091, 完成ID:10000009
# 對話處理進度：37/1091, 完成ID:10001520
# 對話處理進度：38/1091, 完成ID:10001072
# 對話處理進度：39/1091, 完成ID:10000458
# 對話處理進度：40/1091, 完成ID:10000201
# 對話處理進度：41/1091, 完成ID:10000030
# 對話處理進度：42/1091, 完成ID:10000019
# 對話處理進度：43/1091, 完成ID:10000941
# 對話處理進度：44/1091, 完成ID:10001033
# 對話處理進度：45/1091, 完成ID:10001053
# 對話處理進度：46/1091, 完成ID:10001068
# 對話處理進度：47/1091, 完成ID:10000578
# 對話處理進度：48/1091, 完成ID:10000781
# 對話處理進度：49/1091, 完成ID:10000632
# 對話處理進度：50/1091, 完成ID:10000061
# 對話處理進度：51/1091, 完成ID:10000461
# 對話處理進度：52/1091, 完成ID:10000729
# 對話處理進度：53/1091, 完成ID:10001070
# 對話處理進度：54/1091, 完成ID:10001096
# 對話處理進度：55/1091, 完成ID:10001273
# 對話處理進度：56/1091, 完成ID:10000816
# 對話處理進度：57/1091, 完成ID:10000924
# 對話處理進度：58/1091, 完成ID:10001140
# 對話處理進度：59/1091, 完成ID:10000608
# 對話處理進度：60/1091, 完成ID:10000477
# 對話處理進度：61/1091, 完成ID:10000887
# 對話處理進度：62/1091, 完成ID:10001168
# 對話處理進度：63/1091, 完成ID:10001328
# 對話處理進度：64/1091, 完成ID:10000785
# 對話處理進度：65/1091, 完成ID:10000280
# 對話處理進度：66/1091, 完成ID:10000329
# 對話處理進度：67/1091, 完成ID:10000971
# 對話處理進度：68/1091, 完成ID:10000994
# 對話處理進度：69/1091, 完成ID:10000463
# 對話處理進度：70/1091, 完成ID:10000199
# 對話處理進度：71/1091, 完成ID:10000001
# 對話處理進度：72/1091, 完成ID:10000147
# 對話處理進度：73/1091, 完成ID:10000132
# 對話處理進度：74/1091, 完成ID:10000120
# 對話處理進度：75/1091, 完成ID:10000388
# 對話處理進度：76/1091, 完成ID:10000550
# 對話處理進度：77/1091, 完成ID:10001425
# 對話處理進度：78/1091, 完成ID:10000352
# 對話處理進度：79/1091, 完成ID:10000983
# 對話處理進度：80/1091, 完成ID:10000502
# 對話處理進度：81/1091, 完成ID:10000809
# 對話處理進度：82/1091, 完成ID:10001544
# 對話處理進度：83/1091, 完成ID:10000326
# 對話處理進度：84/1091, 完成ID:10001455
# 對話處理進度：85/1091, 完成ID:10000767
# 對話處理進度：86/1091, 完成ID:10001097
# 對話處理進度：87/1091, 完成ID:10000122
# 對話處理進度：88/1091, 完成ID:10000805
# 對話處理進度：89/1091, 完成ID:10000022
# 對話處理進度：90/1091, 完成ID:10000582
# 對話處理進度：91/1091, 完成ID:10000440
# 對話處理進度：92/1091, 完成ID:10001124
# 對話處理進度：93/1091, 完成ID:10000607
# 對話處理進度：94/1091, 完成ID:10000395
# 對話處理進度：95/1091, 完成ID:10001444
# 對話處理進度：96/1091, 完成ID:10000555
# 對話處理進度：97/1091, 完成ID:10000515
# 對話處理進度：98/1091, 完成ID:10000724
# 對話處理進度：99/1091, 完成ID:10000066
# 對話處理進度：100/1091, 完成ID:10001149
# 對話處理進度：101/1091, 完成ID:10001430
# 對話處理進度：102/1091, 完成ID:10000958
# 對話處理進度：103/1091, 完成ID:10000281
# 對話處理進度：104/1091, 完成ID:10001157
# 對話處理進度：105/1091, 完成ID:10000875
# 對話處理進度：106/1091, 完成ID:10000589
# 對話處理進度：107/1091, 完成ID:10000843
# 對話處理進度：108/1091, 完成ID:10000592
# 對話處理進度：109/1091, 完成ID:10001235
# 對話處理進度：110/1091, 完成ID:10000474
# 對話處理進度：111/1091, 完成ID:10000353
# 對話處理進度：112/1091, 完成ID:10000240
# 對話處理進度：113/1091, 完成ID:10000488
# 對話處理進度：114/1091, 完成ID:10001187
# 對話處理進度：115/1091, 完成ID:10000562
# 對話處理進度：116/1091, 完成ID:10000378
# 對話處理進度：117/1091, 完成ID:10001049
# 對話處理進度：118/1091, 完成ID:10000032
# 對話處理進度：119/1091, 完成ID:10001251
# 對話處理進度：120/1091, 完成ID:10000520
# 對話處理進度：121/1091, 完成ID:10001306
# 對話處理進度：122/1091, 完成ID:10001298
# 對話處理進度：123/1091, 完成ID:10001262
# 對話處理進度：124/1091, 完成ID:10000158
# 對話處理進度：125/1091, 完成ID:10000623
# 對話處理進度：126/1091, 完成ID:10000796
# 對話處理進度：127/1091, 完成ID:10000376
# 對話處理進度：128/1091, 完成ID:10001331
# 對話處理進度：129/1091, 完成ID:10000756
# 對話處理進度：130/1091, 完成ID:10000172
# 對話處理進度：131/1091, 完成ID:10000462
# 對話處理進度：132/1091, 完成ID:10001015
# 對話處理進度：133/1091, 完成ID:10000883
# 對話處理進度：134/1091, 完成ID:10000311
# 對話處理進度：135/1091, 完成ID:10001001
# 對話處理進度：136/1091, 完成ID:10000012
# 對話處理進度：137/1091, 完成ID:10001397
# 對話處理進度：138/1091, 完成ID:10001172
# 對話處理進度：139/1091, 完成ID:10000485
# 對話處理進度：140/1091, 完成ID:10001080
# 對話處理進度：141/1091, 完成ID:10001150
# 對話處理進度：142/1091, 完成ID:10000892
# 對話處理進度：143/1091, 完成ID:10000648
# 對話處理進度：144/1091, 完成ID:10000901
# 對話處理進度：145/1091, 完成ID:10000928
# 對話處理進度：146/1091, 完成ID:10000045
# 對話處理進度：147/1091, 完成ID:10001531
# 對話處理進度：148/1091, 完成ID:10001055
# 對話處理進度：149/1091, 完成ID:10000048
# 對話處理進度：150/1091, 完成ID:10000543
# 對話處理進度：151/1091, 完成ID:10000396
# 對話處理進度：152/1091, 完成ID:10001117
# 對話處理進度：153/1091, 完成ID:10001209
# 對話處理進度：154/1091, 完成ID:10000296
# 對話處理進度：155/1091, 完成ID:10000382
# 對話處理進度：156/1091, 完成ID:10000985
# 對話處理進度：157/1091, 完成ID:10000791
# 對話處理進度：158/1091, 完成ID:10000471
# 對話處理進度：159/1091, 完成ID:10000270
# 對話處理進度：160/1091, 完成ID:10000760
# 對話處理進度：161/1091, 完成ID:10001237
# 對話處理進度：162/1091, 完成ID:10000074
# 對話處理進度：163/1091, 完成ID:10001031
# 對話處理進度：164/1091, 完成ID:10001382
# 對話處理進度：165/1091, 完成ID:10001092
# 對話處理進度：166/1091, 完成ID:10001477
# 對話處理進度：167/1091, 完成ID:10001028
# 對話處理進度：168/1091, 完成ID:10000023
# 對話處理進度：169/1091, 完成ID:10000801
# 對話處理進度：170/1091, 完成ID:10000568
# 對話處理進度：171/1091, 完成ID:10001319
# 對話處理進度：172/1091, 完成ID:10000599
# 對話處理進度：173/1091, 完成ID:10000446
# 對話處理進度：174/1091, 完成ID:10000959
# 對話處理進度：175/1091, 完成ID:10001485
# 對話處理進度：176/1091, 完成ID:10001115
# 對話處理進度：177/1091, 完成ID:10000948
# 對話處理進度：178/1091, 完成ID:10000333
# 對話處理進度：179/1091, 完成ID:10000910
# 對話處理進度：180/1091, 完成ID:10000938
# 對話處理進度：181/1091, 完成ID:10000534
# 對話處理進度：182/1091, 完成ID:10000979
# 對話處理進度：183/1091, 完成ID:10001420
# 對話處理進度：184/1091, 完成ID:10001087
# 對話處理進度：185/1091, 完成ID:10000503
# 對話處理進度：186/1091, 完成ID:10000206
# 對話處理進度：187/1091, 完成ID:10000666
# 對話處理進度：188/1091, 完成ID:D9I42SFBSU
# 對話處理進度：189/1091, 完成ID:10000814
# 對話處理進度：190/1091, 完成ID:10000164
# 對話處理進度：191/1091, 完成ID:10000765
# 對話處理進度：192/1091, 完成ID:10000249
# 對話處理進度：193/1091, 完成ID:10001355
# 對話處理進度：194/1091, 完成ID:10001308
# 對話處理進度：195/1091, 完成ID:10000893
# 對話處理進度：196/1091, 完成ID:10000242
# 對話處理進度：197/1091, 完成ID:10000013
# 對話處理進度：198/1091, 完成ID:10001065
# 對話處理進度：199/1091, 完成ID:10001139
# 對話處理進度：200/1091, 完成ID:10000469
# 對話處理進度：201/1091, 完成ID:10001415
# 對話處理進度：202/1091, 完成ID:10000399
# 對話處理進度：203/1091, 完成ID:10001212
# 對話處理進度：204/1091, 完成ID:10001016
# 對話處理進度：205/1091, 完成ID:10000119
# 對話處理進度：206/1091, 完成ID:10000272
# 對話處理進度：207/1091, 完成ID:10000549
# 對話處理進度：208/1091, 完成ID:10000325
# 對話處理進度：209/1091, 完成ID:10001238
# 對話處理進度：210/1091, 完成ID:10001335
# 對話處理進度：211/1091, 完成ID:10000245
# 對話處理進度：212/1091, 完成ID:10000251
# 對話處理進度：213/1091, 完成ID:10001011
# 對話處理進度：214/1091, 完成ID:10000103
# 對話處理進度：215/1091, 完成ID:10001388
# 對話處理進度：216/1091, 完成ID:10000042
# 對話處理進度：217/1091, 完成ID:10000198
# 對話處理進度：218/1091, 完成ID:10000603
# 對話處理進度：219/1091, 完成ID:10001037
# 對話處理進度：220/1091, 完成ID:10000433
# 對話處理進度：221/1091, 完成ID:10000898
# 對話處理進度：222/1091, 完成ID:10000973
# 對話處理進度：223/1091, 完成ID:10000235
# 對話處理進度：224/1091, 完成ID:10000361
# 對話處理進度：225/1091, 完成ID:10001045
# 對話處理進度：226/1091, 完成ID:10001215
# 對話處理進度：227/1091, 完成ID:10000033
# 對話處理進度：228/1091, 完成ID:10001423
# 對話處理進度：229/1091, 完成ID:10001242
# 對話處理進度：230/1091, 完成ID:10000512
# 對話處理進度：231/1091, 完成ID:10000974
# 對話處理進度：232/1091, 完成ID:10001126
# 對話處理進度：233/1091, 完成ID:10001040
# 對話處理進度：234/1091, 完成ID:10000200
# 對話處理進度：235/1091, 完成ID:10000871
# 對話處理進度：236/1091, 完成ID:10000429
# 對話處理進度：237/1091, 完成ID:10000368
# 對話處理進度：238/1091, 完成ID:10001047
# 對話處理進度：239/1091, 完成ID:10001162
# 對話處理進度：240/1091, 完成ID:10000059
# 對話處理進度：241/1091, 完成ID:10000386
# 對話處理進度：242/1091, 完成ID:10000065
# 對話處理進度：243/1091, 完成ID:10001333
# 對話處理進度：244/1091, 完成ID:10000815
# 對話處理進度：245/1091, 完成ID:10000209
# 對話處理進度：246/1091, 完成ID:10001051
# 對話處理進度：247/1091, 完成ID:10000947
# 對話處理進度：248/1091, 完成ID:10000793
# 對話處理進度：249/1091, 完成ID:10001151
# 對話處理進度：250/1091, 完成ID:10001322
# 對話處理進度：251/1091, 完成ID:10000680
# 對話處理進度：252/1091, 完成ID:10000411
# 對話處理進度：253/1091, 完成ID:10001189
# 對話處理進度：254/1091, 完成ID:10001447
# 對話處理進度：255/1091, 完成ID:10001196
# 對話處理進度：256/1091, 完成ID:10001476
# 對話處理進度：257/1091, 完成ID:10000713
# 對話處理進度：258/1091, 完成ID:10001156
# 對話處理進度：259/1091, 完成ID:10000583
# 對話處理進度：260/1091, 完成ID:10001378
# 對話處理進度：261/1091, 完成ID:10000784
# 對話處理進度：262/1091, 完成ID:10001082
# 對話處理進度：263/1091, 完成ID:10000818
# 對話處理進度：264/1091, 完成ID:10000537
# 對話處理進度：265/1091, 完成ID:10000634
# 對話處理進度：266/1091, 完成ID:10000755
# 對話處理進度：267/1091, 完成ID:10001516
# 對話處理進度：268/1091, 完成ID:10000817
# 對話處理進度：269/1091, 完成ID:10000166
# 對話處理進度：270/1091, 完成ID:10001163
# 對話處理進度：271/1091, 完成ID:10000556
# 對話處理進度：272/1091, 完成ID:10000100
# 對話處理進度：273/1091, 完成ID:10000527
# 對話處理進度：274/1091, 完成ID:10001271
# 對話處理進度：275/1091, 完成ID:10000624
# 對話處理進度：276/1091, 完成ID:10001469
# 對話處理進度：277/1091, 完成ID:10001206
# 對話處理進度：278/1091, 完成ID:10000465
# 對話處理進度：279/1091, 完成ID:10000984
# 對話處理進度：280/1091, 完成ID:10000125
# 對話處理進度：281/1091, 完成ID:10001191
# 對話處理進度：282/1091, 完成ID:10001141
# 對話處理進度：283/1091, 完成ID:10001510
# 對話處理進度：284/1091, 完成ID:10000229
# 對話處理進度：285/1091, 完成ID:10000667
# 對話處理進度：286/1091, 完成ID:10001366
# 對話處理進度：287/1091, 完成ID:10000204
# 對話處理進度：288/1091, 完成ID:10000825
# 對話處理進度：289/1091, 完成ID:10001257
# 對話處理進度：290/1091, 完成ID:10000668
# 對話處理進度：291/1091, 完成ID:10001344
# 對話處理進度：292/1091, 完成ID:10000214
# 對話處理進度：293/1091, 完成ID:10000004
# 對話處理進度：294/1091, 完成ID:10000730
# 對話處理進度：295/1091, 完成ID:10000018
# 對話處理進度：296/1091, 完成ID:10000990
# 對話處理進度：297/1091, 完成ID:10000002
# 對話處理進度：298/1091, 完成ID:10000412
# 對話處理進度：299/1091, 完成ID:10000259
# 對話處理進度：300/1091, 完成ID:10001171
# 對話處理進度：301/1091, 完成ID:10000523
# 對話處理進度：302/1091, 完成ID:10001218
# 對話處理進度：303/1091, 完成ID:10000745
# 對話處理進度：304/1091, 完成ID:10000558
# 對話處理進度：305/1091, 完成ID:10000484
# 對話處理進度：306/1091, 完成ID:10001460
# 對話處理進度：307/1091, 完成ID:10000738
# 對話處理進度：308/1091, 完成ID:10000977
# 對話處理進度：309/1091, 完成ID:10001392
# 對話處理進度：310/1091, 完成ID:10000015
# 對話處理進度：311/1091, 完成ID:10001299
# 對話處理進度：312/1091, 完成ID:10001463
# 對話處理進度：313/1091, 完成ID:10000743
# 對話處理進度：314/1091, 完成ID:10000317
# 對話處理進度：315/1091, 完成ID:10000577
# 對話處理進度：316/1091, 完成ID:10001527
# 對話處理進度：317/1091, 完成ID:10000631
# 對話處理進度：318/1091, 完成ID:10000917
# 對話處理進度：319/1091, 完成ID:10000184
# 對話處理進度：320/1091, 完成ID:10000435
# 對話處理進度：321/1091, 完成ID:10000758
# 對話處理進度：322/1091, 完成ID:10001221
# 對話處理進度：323/1091, 完成ID:10000529
# 對話處理進度：324/1091, 完成ID:10000542
# 對話處理進度：325/1091, 完成ID:10001480
# 對話處理進度：326/1091, 完成ID:10001511
# 對話處理進度：327/1091, 完成ID:10000980
# 對話處理進度：328/1091, 完成ID:10000418
# 對話處理進度：329/1091, 完成ID:10000926
# 對話處理進度：330/1091, 完成ID:10001498
# 對話處理進度：331/1091, 完成ID:10001214
# 對話處理進度：332/1091, 完成ID:10001131
# 對話處理進度：333/1091, 完成ID:10000618
# 對話處理進度：334/1091, 完成ID:10000678
# 對話處理進度：335/1091, 完成ID:10000337
# 對話處理進度：336/1091, 完成ID:10000414
# 對話處理進度：337/1091, 完成ID:10000134
# 對話處理進度：338/1091, 完成ID:10000138
# 對話處理進度：339/1091, 完成ID:10001094
# 對話處理進度：340/1091, 完成ID:10000842
# 對話處理進度：341/1091, 完成ID:10000700
# 對話處理進度：342/1091, 完成ID:10000151
# 對話處理進度：343/1091, 完成ID:10001505
# 對話處理進度：344/1091, 完成ID:10000197
# 對話處理進度：345/1091, 完成ID:10000664
# 對話處理進度：346/1091, 完成ID:10001546
# 對話處理進度：347/1091, 完成ID:10000393
# 對話處理進度：348/1091, 完成ID:10001248
# 對話處理進度：349/1091, 完成ID:10000496
# 對話處理進度：350/1091, 完成ID:10000754
# 對話處理進度：351/1091, 完成ID:10000772
# 對話處理進度：352/1091, 完成ID:10000487
# 對話處理進度：353/1091, 完成ID:10001407
# 對話處理進度：354/1091, 完成ID:10000854
# 對話處理進度：355/1091, 完成ID:10000966
# 對話處理進度：356/1091, 完成ID:10001349
# 對話處理進度：357/1091, 完成ID:10000244
# 對話處理進度：358/1091, 完成ID:10001108
# 對話處理進度：359/1091, 完成ID:10001288
# 對話處理進度：360/1091, 完成ID:10000220
# 對話處理進度：361/1091, 完成ID:10000746
# 對話處理進度：362/1091, 完成ID:10001052
# 對話處理進度：363/1091, 完成ID:10001004
# 對話處理進度：364/1091, 完成ID:10000846
# 對話處理進度：365/1091, 完成ID:10001276
# 對話處理進度：366/1091, 完成ID:10001250
# 對話處理進度：367/1091, 完成ID:10000256
# 對話處理進度：368/1091, 完成ID:10001266
# 對話處理進度：369/1091, 完成ID:10000894
# 對話處理進度：370/1091, 完成ID:10001222
# 對話處理進度：371/1091, 完成ID:10001062
# 對話處理進度：372/1091, 完成ID:10001549
# 對話處理進度：373/1091, 完成ID:10000062
# 對話處理進度：374/1091, 完成ID:10000212
# 對話處理進度：375/1091, 完成ID:10000884
# 對話處理進度：376/1091, 完成ID:MJJ3AFBRSN
# 對話處理進度：377/1091, 完成ID:10001347
# 對話處理進度：378/1091, 完成ID:10000083
# 對話處理進度：379/1091, 完成ID:10000879
# 對話處理進度：380/1091, 完成ID:10001399
# 對話處理進度：381/1091, 完成ID:10000899
# 對話處理進度：382/1091, 完成ID:10001167
# 對話處理進度：383/1091, 完成ID:10000115
# 對話處理進度：384/1091, 完成ID:10001056
# 對話處理進度：385/1091, 完成ID:10001414
# 對話處理進度：386/1091, 完成ID:10000826
# 對話處理進度：387/1091, 完成ID:10000335
# 對話處理進度：388/1091, 完成ID:10001008
# 對話處理進度：389/1091, 完成ID:10001412
# 對話處理進度：390/1091, 完成ID:10000237
# 對話處理進度：391/1091, 完成ID:10000519
# 對話處理進度：392/1091, 完成ID:10001374
# 對話處理進度：393/1091, 完成ID:10001152
# 對話處理進度：394/1091, 完成ID:10000355
# 對話處理進度：395/1091, 完成ID:10000950
# 對話處理進度：396/1091, 完成ID:10001402
# 對話處理進度：397/1091, 完成ID:10000629
# 對話處理進度：398/1091, 完成ID:10001133
# 對話處理進度：399/1091, 完成ID:10001449
# 對話處理進度：400/1091, 完成ID:10000869
# 對話處理進度：401/1091, 完成ID:10001410
# 對話處理進度：402/1091, 完成ID:10001405
# 對話處理進度：403/1091, 完成ID:10000341
# 對話處理進度：404/1091, 完成ID:10000889
# 對話處理進度：405/1091, 完成ID:10000610
# 對話處理進度：406/1091, 完成ID:10000483
# 對話處理進度：407/1091, 完成ID:10000614
# 對話處理進度：408/1091, 完成ID:10001136
# 對話處理進度：409/1091, 完成ID:10000911
# 對話處理進度：410/1091, 完成ID:10000967
# 對話處理進度：411/1091, 完成ID:10000714
# 對話處理進度：412/1091, 完成ID:10000581
# 對話處理進度：413/1091, 完成ID:10000506
# 對話處理進度：414/1091, 完成ID:10000117
# 對話處理進度：415/1091, 完成ID:10000553
# 對話處理進度：416/1091, 完成ID:10001419
# 對話處理進度：417/1091, 完成ID:10000076
# 對話處理進度：418/1091, 完成ID:10000710
# 對話處理進度：419/1091, 完成ID:10000836
# 對話處理進度：420/1091, 完成ID:10000922
# 對話處理進度：421/1091, 完成ID:10001224
# 對話處理進度：422/1091, 完成ID:10000088
# 對話處理進度：423/1091, 完成ID:10000507
# 對話處理進度：424/1091, 完成ID:10000328
# 對話處理進度：425/1091, 完成ID:10000930
# 對話處理進度：426/1091, 完成ID:10000586
# 對話處理進度：427/1091, 完成ID:10000271
# 對話處理進度：428/1091, 完成ID:10001438
# 對話處理進度：429/1091, 完成ID:10000160
# 對話處理進度：430/1091, 完成ID:10000385
# 對話處理進度：431/1091, 完成ID:10001343
# 對話處理進度：432/1091, 完成ID:10000372
# 對話處理進度：433/1091, 完成ID:10000654
# 對話處理進度：434/1091, 完成ID:10000183
# 對話處理進度：435/1091, 完成ID:10000460
# 對話處理進度：436/1091, 完成ID:10000236
# 對話處理進度：437/1091, 完成ID:10000685
# 對話處理進度：438/1091, 完成ID:10001199
# 對話處理進度：439/1091, 完成ID:10000567
# 對話處理進度：440/1091, 完成ID:10001508
# 對話處理進度：441/1091, 完成ID:10000807
# 對話處理進度：442/1091, 完成ID:10000078
# 對話處理進度：443/1091, 完成ID:10001297
# 對話處理進度：444/1091, 完成ID:10001334
# 對話處理進度：445/1091, 完成ID:10001372
# 對話處理進度：446/1091, 完成ID:10000438
# 對話處理進度：447/1091, 完成ID:10000475
# 對話處理進度：448/1091, 完成ID:10001440
# 對話處理進度：449/1091, 完成ID:10000265
# 對話處理進度：450/1091, 完成ID:10000284
# 對話處理進度：451/1091, 完成ID:10000962
# 對話處理進度：452/1091, 完成ID:10000419
# 對話處理進度：453/1091, 完成ID:10000839
# 對話處理進度：454/1091, 完成ID:10000636
# 對話處理進度：455/1091, 完成ID:10000735
# 對話處理進度：456/1091, 完成ID:10001459
# 對話處理進度：457/1091, 完成ID:UHCE66FHZ2
# 對話處理進度：458/1091, 完成ID:10001503
# 對話處理進度：459/1091, 完成ID:10000104
# 對話處理進度：460/1091, 完成ID:10001377
# 對話處理進度：461/1091, 完成ID:10000093
# 對話處理進度：462/1091, 完成ID:10000180
# 對話處理進度：463/1091, 完成ID:10000611
# 對話處理進度：464/1091, 完成ID:10001342
# 對話處理進度：465/1091, 完成ID:10000593
# 對話處理進度：466/1091, 完成ID:10000830
# 對話處理進度：467/1091, 完成ID:10000268
# 對話處理進度：468/1091, 完成ID:10000422
# 對話處理進度：469/1091, 完成ID:10000277
# 對話處理進度：470/1091, 完成ID:10001174
# 對話處理進度：471/1091, 完成ID:10001327
# 對話處理進度：472/1091, 完成ID:10000601
# 對話處理進度：473/1091, 完成ID:10000909
# 對話處理進度：474/1091, 完成ID:10001041
# 對話處理進度：475/1091, 完成ID:10001249
# 對話處理進度：476/1091, 完成ID:10000472
# 對話處理進度：477/1091, 完成ID:10000690
# 對話處理進度：478/1091, 完成ID:10000975
# 對話處理進度：479/1091, 完成ID:10001075
# 對話處理進度：480/1091, 完成ID:10001233
# 對話處理進度：481/1091, 完成ID:10001545
# 對話處理進度：482/1091, 完成ID:10000669
# 對話處理進度：483/1091, 完成ID:10001441
# 對話處理進度：484/1091, 完成ID:10001504
# 對話處理進度：485/1091, 完成ID:10000360
# 對話處理進度：486/1091, 完成ID:10000402
# 對話處理進度：487/1091, 完成ID:10001428
# 對話處理進度：488/1091, 完成ID:10000423
# 對話處理進度：489/1091, 完成ID:10001026
# 對話處理進度：490/1091, 完成ID:10000665
# 對話處理進度：491/1091, 完成ID:10000410
# 對話處理進度：492/1091, 完成ID:10000986
# 對話處理進度：493/1091, 完成ID:10000786
# 對話處理進度：494/1091, 完成ID:10001524
# 對話處理進度：495/1091, 完成ID:10000557
# 對話處理進度：496/1091, 完成ID:10000682
# 對話處理進度：497/1091, 完成ID:10001353
# 對話處理進度：498/1091, 完成ID:10000764
# 對話處理進度：499/1091, 完成ID:10000447
# 對話處理進度：500/1091, 完成ID:10001541
# 對話處理進度：501/1091, 完成ID:QKCDCUXQUQ
# 對話處理進度：502/1091, 完成ID:10001116
# 對話處理進度：503/1091, 完成ID:10001354
# 對話處理進度：504/1091, 完成ID:10000452
# 對話處理進度：505/1091, 完成ID:10001127
# 對話處理進度：506/1091, 完成ID:10000717
# 對話處理進度：507/1091, 完成ID:10001385
# 對話處理進度：508/1091, 完成ID:10000489
# 對話處理進度：509/1091, 完成ID:10000177
# 對話處理進度：510/1091, 完成ID:YSDAGQXBFO
# 對話處理進度：511/1091, 完成ID:10000528
# 對話處理進度：512/1091, 完成ID:10000617
# 對話處理進度：513/1091, 完成ID:10001478
# 對話處理進度：514/1091, 完成ID:10000051
# 對話處理進度：515/1091, 完成ID:10000628
# 對話處理進度：516/1091, 完成ID:10000358
# 對話處理進度：517/1091, 完成ID:10001202
# 對話處理進度：518/1091, 完成ID:10000250
# 對話處理進度：519/1091, 完成ID:10000026
# 對話處理進度：520/1091, 完成ID:10001317
# 對話處理進度：521/1091, 完成ID:10000788
# 對話處理進度：522/1091, 完成ID:10000960
# 對話處理進度：523/1091, 完成ID:10000258
# 對話處理進度：524/1091, 完成ID:10000573
# 對話處理進度：525/1091, 完成ID:10000208
# 對話處理進度：526/1091, 完成ID:10000511
# 對話處理進度：527/1091, 完成ID:10001401
# 對話處理進度：528/1091, 完成ID:10001120
# 對話處理進度：529/1091, 完成ID:10001058
# 對話處理進度：530/1091, 完成ID:10000676
# 對話處理進度：531/1091, 完成ID:10001179
# 對話處理進度：532/1091, 完成ID:10000456
# 對話處理進度：533/1091, 完成ID:10001009
# 對話處理進度：534/1091, 完成ID:10001284
# 對話處理進度：535/1091, 完成ID:10001535
# 對話處理進度：536/1091, 完成ID:10001014
# 對話處理進度：537/1091, 完成ID:10000106
# 對話處理進度：538/1091, 完成ID:10001361
# 對話處理進度：539/1091, 完成ID:10000094
# 對話處理進度：540/1091, 完成ID:10000210
# 對話處理進度：541/1091, 完成ID:10001291
# 對話處理進度：542/1091, 完成ID:10000681
# 對話處理進度：543/1091, 完成ID:10001538
# 對話處理進度：544/1091, 完成ID:10000099
# 對話處理進度：545/1091, 完成ID:10000751
# 對話處理進度：546/1091, 完成ID:10000972
# 對話處理進度：547/1091, 完成ID:10000540
# 對話處理進度：548/1091, 完成ID:10000248
# 對話處理進度：549/1091, 完成ID:10001103
# 對話處理進度：550/1091, 完成ID:10000095
# 對話處理進度：551/1091, 完成ID:10001132
# 對話處理進度：552/1091, 完成ID:10000171
# 對話處理進度：553/1091, 完成ID:10001109
# 對話處理進度：554/1091, 完成ID:10000840
# 對話處理進度：555/1091, 完成ID:10000109
# 對話處理進度：556/1091, 完成ID:10000988
# 對話處理進度：557/1091, 完成ID:10000961
# 對話處理進度：558/1091, 完成ID:10000247
# 對話處理進度：559/1091, 完成ID:10000238
# 對話處理進度：560/1091, 完成ID:10000956
# 對話處理進度：561/1091, 完成ID:10001358
# 對話處理進度：562/1091, 完成ID:10001530
# 對話處理進度：563/1091, 完成ID:10001048
# 對話處理進度：564/1091, 完成ID:10001261
# 對話處理進度：565/1091, 完成ID:10000334
# 對話處理進度：566/1091, 完成ID:10001043
# 對話處理進度：567/1091, 完成ID:10000851
# 對話處理進度：568/1091, 完成ID:10001226
# 對話處理進度：569/1091, 完成ID:10001099
# 對話處理進度：570/1091, 完成ID:10000222
# 對話處理進度：571/1091, 完成ID:10001277
# 對話處理進度：572/1091, 完成ID:10000723
# 對話處理進度：573/1091, 完成ID:10000695
# 對話處理進度：574/1091, 完成ID:10000701
# 對話處理進度：575/1091, 完成ID:10001153
# 對話處理進度：576/1091, 完成ID:10000436
# 對話處理進度：577/1091, 完成ID:10000770
# 對話處理進度：578/1091, 完成ID:10000397
# 對話處理進度：579/1091, 完成ID:10000827
# 對話處理進度：580/1091, 完成ID:10000467
# 對話處理進度：581/1091, 完成ID:10000087
# 對話處理進度：582/1091, 完成ID:9N2KXA8443
# 對話處理進度：583/1091, 完成ID:10000588
# 對話處理進度：584/1091, 完成ID:10000319
# 對話處理進度：585/1091, 完成ID:10000179
# 對話處理進度：586/1091, 完成ID:10000313
# 對話處理進度：587/1091, 完成ID:10001201
# 對話處理進度：588/1091, 完成ID:10001110
# 對話處理進度：589/1091, 完成ID:10000321
# 對話處理進度：590/1091, 完成ID:10001217
# 對話處理進度：591/1091, 完成ID:10000693
# 對話處理進度：592/1091, 完成ID:10000533
# 對話處理進度：593/1091, 完成ID:10000444
# 對話處理進度：594/1091, 完成ID:10001012
# 對話處理進度：595/1091, 完成ID:10001329
# 對話處理進度：596/1091, 完成ID:10000955
# 對話處理進度：597/1091, 完成ID:10000535
# 對話處理進度：598/1091, 完成ID:10001064
# 對話處理進度：599/1091, 完成ID:10000428
# 對話處理進度：600/1091, 完成ID:10000612
# 對話處理進度：601/1091, 完成ID:10001318
# 對話處理進度：602/1091, 完成ID:10000532
# 對話處理進度：603/1091, 完成ID:10000383
# 對話處理進度：604/1091, 完成ID:10000920
# 對話處理進度：605/1091, 完成ID:GX9XZN502W
# 對話處理進度：606/1091, 完成ID:10000620
# 對話處理進度：607/1091, 完成ID:10001086
# 對話處理進度：608/1091, 完成ID:10000047
# 對話處理進度：609/1091, 完成ID:10000672
# 對話處理進度：610/1091, 完成ID:10001159
# 對話處理進度：611/1091, 完成ID:10000708
# 對話處理進度：612/1091, 完成ID:10000937
# 對話處理進度：613/1091, 完成ID:10000824
# 對話處理進度：614/1091, 完成ID:10001479
# 對話處理進度：615/1091, 完成ID:10000916
# 對話處理進度：616/1091, 完成ID:10000407
# 對話處理進度：617/1091, 完成ID:10000362
# 對話處理進度：618/1091, 完成ID:10000044
# 對話處理進度：619/1091, 完成ID:10000224
# 對話處理進度：620/1091, 完成ID:10000020
# 對話處理進度：621/1091, 完成ID:10001409
# 對話處理進度：622/1091, 完成ID:10000605
# 對話處理進度：623/1091, 完成ID:10001539
# 對話處理進度：624/1091, 完成ID:10000766
# 對話處理進度：625/1091, 完成ID:10000118
# 對話處理進度：626/1091, 完成ID:10000580
# 對話處理進度：627/1091, 完成ID:10000981
# 對話處理進度：628/1091, 完成ID:10000498
# 對話處理進度：629/1091, 完成ID:10001408
# 對話處理進度：630/1091, 完成ID:10001433
# 對話處理進度：631/1091, 完成ID:10001207
# 對話處理進度：632/1091, 完成ID:10000304
# 對話處理進度：633/1091, 完成ID:10000500
# 對話處理進度：634/1091, 完成ID:10001321
# 對話處理進度：635/1091, 完成ID:10000596
# 對話處理進度：636/1091, 完成ID:10000058
# 對話處理進度：637/1091, 完成ID:10001523
# 對話處理進度：638/1091, 完成ID:10000734
# 對話處理進度：639/1091, 完成ID:10001499
# 對話處理進度：640/1091, 完成ID:10000168
# 對話處理進度：641/1091, 完成ID:10001243
# 對話處理進度：642/1091, 完成ID:10000306
# 對話處理進度：643/1091, 完成ID:10000063
# 對話處理進度：644/1091, 完成ID:10001137
# 對話處理進度：645/1091, 完成ID:10001129
# 對話處理進度：646/1091, 完成ID:10001533
# 對話處理進度：647/1091, 完成ID:10000318
# 對話處理進度：648/1091, 完成ID:10000387
# 對話處理進度：649/1091, 完成ID:10000771
# 對話處理進度：650/1091, 完成ID:10000314
# 對話處理進度：651/1091, 完成ID:10000524
# 對話處理進度：652/1091, 完成ID:10000702
# 對話處理進度：653/1091, 完成ID:10000089
# 對話處理進度：654/1091, 完成ID:10000706
# 對話處理進度：655/1091, 完成ID:10001106
# 對話處理進度：656/1091, 完成ID:10000226
# 對話處理進度：657/1091, 完成ID:10001197
# 對話處理進度：658/1091, 完成ID:10001231
# 對話處理進度：659/1091, 完成ID:10000712
# 對話處理進度：660/1091, 完成ID:10000572
# 對話處理進度：661/1091, 完成ID:10000211
# 對話處理進度：662/1091, 完成ID:10001542
# 對話處理進度：663/1091, 完成ID:10000759
# 對話處理進度：664/1091, 完成ID:10001389
# 對話處理進度：665/1091, 完成ID:10001003
# 對話處理進度：666/1091, 完成ID:10000152
# 對話處理進度：667/1091, 完成ID:10000322
# 對話處理進度：668/1091, 完成ID:10001032
# 對話處理進度：669/1091, 完成ID:10001020
# 對話處理進度：670/1091, 完成ID:10000510
# 對話處理進度：671/1091, 完成ID:10000848
# 對話處理進度：672/1091, 完成ID:10000688
# 對話處理進度：673/1091, 完成ID:10000127
# 對話處理進度：674/1091, 完成ID:10000060
# 對話處理進度：675/1091, 完成ID:10001281
# 對話處理進度：676/1091, 完成ID:10000742
# 對話處理進度：677/1091, 完成ID:10000885
# 對話處理進度：678/1091, 完成ID:10000526
# 對話處理進度：679/1091, 完成ID:10000196
# 對話處理進度：680/1091, 完成ID:10000660
# 對話處理進度：681/1091, 完成ID:10000591
# 對話處理進度：682/1091, 完成ID:10000406
# 對話處理進度：683/1091, 完成ID:K1XIRGTEDG
# 對話處理進度：684/1091, 完成ID:10000473
# 對話處理進度：685/1091, 完成ID:10001121
# 對話處理進度：686/1091, 完成ID:10000480
# 對話處理進度：687/1091, 完成ID:10000891
# 對話處理進度：688/1091, 完成ID:10001351
# 對話處理進度：689/1091, 完成ID:10000421
# 對話處理進度：690/1091, 完成ID:10001125
# 對話處理進度：691/1091, 完成ID:10001054
# 對話處理進度：692/1091, 完成ID:10000416
# 對話處理進度：693/1091, 完成ID:10001042
# 對話處理進度：694/1091, 完成ID:10000014
# 對話處理進度：695/1091, 完成ID:10000978
# 對話處理進度：696/1091, 完成ID:10000789
# 對話處理進度：697/1091, 完成ID:10001286
# 對話處理進度：698/1091, 完成ID:10000597
# 對話處理進度：699/1091, 完成ID:10000590
# 對話處理進度：700/1091, 完成ID:10000161
# 對話處理進度：701/1091, 完成ID:10001118
# 對話處理進度：702/1091, 完成ID:10001244
# 對話處理進度：703/1091, 完成ID:10001330
# 對話處理進度：704/1091, 完成ID:10000430
# 對話處理進度：705/1091, 完成ID:10000571
# 對話處理進度：706/1091, 完成ID:10001454
# 對話處理進度：707/1091, 完成ID:10000769
# 對話處理進度：708/1091, 完成ID:10000096
# 對話處理進度：709/1091, 完成ID:10000569
# 對話處理進度：710/1091, 完成ID:10000081
# 對話處理進度：711/1091, 完成ID:10000391
# 對話處理進度：712/1091, 完成ID:10000560
# 對話處理進度：713/1091, 完成ID:10000090
# 對話處理進度：714/1091, 完成ID:10001066
# 對話處理進度：715/1091, 完成ID:10001165
# 對話處理進度：716/1091, 完成ID:10000982
# 對話處理進度：717/1091, 完成ID:10001293
# 對話處理進度：718/1091, 完成ID:10000454
# 對話處理進度：719/1091, 完成ID:10000775
# 對話處理進度：720/1091, 完成ID:10000143
# 對話處理進度：721/1091, 完成ID:10000595
# 對話處理進度：722/1091, 完成ID:10000188
# 對話處理進度：723/1091, 完成ID:10000933
# 對話處理進度：724/1091, 完成ID:10000625
# 對話處理進度：725/1091, 完成ID:10000999
# 對話處理進度：726/1091, 完成ID:10001525
# 對話處理進度：727/1091, 完成ID:10000918
# 對話處理進度：728/1091, 完成ID:10001000
# 對話處理進度：729/1091, 完成ID:10000501
# 對話處理進度：730/1091, 完成ID:10000426
# 對話處理進度：731/1091, 完成ID:10000230
# 對話處理進度：732/1091, 完成ID:10001147
# 對話處理進度：733/1091, 完成ID:10001267
# 對話處理進度：734/1091, 完成ID:10000704
# 對話處理進度：735/1091, 完成ID:10001270
# 對話處理進度：736/1091, 完成ID:10001135
# 對話處理進度：737/1091, 完成ID:10000989
# 對話處理進度：738/1091, 完成ID:10000741
# 對話處理進度：739/1091, 完成ID:10001376
# 對話處理進度：740/1091, 完成ID:10000401
# 對話處理進度：741/1091, 完成ID:10000107
# 對話處理進度：742/1091, 完成ID:10001484
# 對話處理進度：743/1091, 完成ID:10001323
# 對話處理進度：744/1091, 完成ID:10001275
# 對話處理進度：745/1091, 完成ID:10001307
# 對話處理進度：746/1091, 完成ID:10000162
# 對話處理進度：747/1091, 完成ID:10000346
# 對話處理進度：748/1091, 完成ID:10001537
# 對話處理進度：749/1091, 完成ID:10000153
# 對話處理進度：750/1091, 完成ID:10001081
# 對話處理進度：751/1091, 完成ID:10000052
# 對話處理進度：752/1091, 完成ID:10000991
# 對話處理進度：753/1091, 完成ID:10001482
# 對話處理進度：754/1091, 完成ID:10000157
# 對話處理進度：755/1091, 完成ID:10000829
# 對話處理進度：756/1091, 完成ID:10000606
# 對話處理進度：757/1091, 完成ID:10000752
# 對話處理進度：758/1091, 完成ID:10000613
# 對話處理進度：759/1091, 完成ID:10000790
# 對話處理進度：760/1091, 完成ID:10000658
# 對話處理進度：761/1091, 完成ID:10000604
# 對話處理進度：762/1091, 完成ID:10001173
# 對話處理進度：763/1091, 完成ID:10000278
# 對話處理進度：764/1091, 完成ID:10000405
# 對話處理進度：765/1091, 完成ID:10000635
# 對話處理進度：766/1091, 完成ID:10001007
# 對話處理進度：767/1091, 完成ID:10001373
# 對話處理進度：768/1091, 完成ID:10000420
# 對話處理進度：769/1091, 完成ID:10000092
# 對話處理進度：770/1091, 完成ID:10000970
# 對話處理進度：771/1091, 完成ID:10001395
# 對話處理進度：772/1091, 完成ID:10001186
# 對話處理進度：773/1091, 完成ID:10000142
# 對話處理進度：774/1091, 完成ID:10000673
# 對話處理進度：775/1091, 完成ID:10000102
# 對話處理進度：776/1091, 完成ID:10000298
# 對話處理進度：777/1091, 完成ID:10001426
# 對話處理進度：778/1091, 完成ID:10001027
# 對話處理進度：779/1091, 完成ID:10000225
# 對話處理進度：780/1091, 完成ID:10001255
# 對話處理進度：781/1091, 完成ID:10001436
# 對話處理進度：782/1091, 完成ID:10000027
# 對話處理進度：783/1091, 完成ID:10000564
# 對話處理進度：784/1091, 完成ID:10000091
# 對話處理進度：785/1091, 完成ID:10000359
# 對話處理進度：786/1091, 完成ID:10000193
# 對話處理進度：787/1091, 完成ID:10000661
# 對話處理進度：788/1091, 完成ID:10000804
# 對話處理進度：789/1091, 完成ID:10001143
# 對話處理進度：790/1091, 完成ID:10001502
# 對話處理進度：791/1091, 完成ID:10000762
# 對話處理進度：792/1091, 完成ID:10000239
# 對話處理進度：793/1091, 完成ID:10000260
# 對話處理進度：794/1091, 完成ID:10001220
# 對話處理進度：795/1091, 完成ID:10000888
# 對話處理進度：796/1091, 完成ID:10001219
# 對話處理進度：797/1091, 完成ID:10001406
# 對話處理進度：798/1091, 完成ID:10001198
# 對話處理進度：799/1091, 完成ID:10001456
# 對話處理進度：800/1091, 完成ID:10000876
# 對話處理進度：801/1091, 完成ID:10000228
# 對話處理進度：802/1091, 完成ID:10000615
# 對話處理進度：803/1091, 完成ID:10000263
# 對話處理進度：804/1091, 完成ID:10000046
# 對話處理進度：805/1091, 完成ID:10001509
# 對話處理進度：806/1091, 完成ID:10000274
# 對話處理進度：807/1091, 完成ID:10001263
# 對話處理進度：808/1091, 完成ID:10001170
# 對話處理進度：809/1091, 完成ID:10000716
# 對話處理進度：810/1091, 完成ID:10000017
# 對話處理進度：811/1091, 完成ID:10001239
# 對話處理進度：812/1091, 完成ID:10001123
# 對話處理進度：813/1091, 完成ID:10000056
# 對話處理進度：814/1091, 完成ID:10001241
# 對話處理進度：815/1091, 完成ID:SMEYOJWRBA
# 對話處理進度：816/1091, 完成ID:10000343
# 對話處理進度：817/1091, 完成ID:10000703
# 對話處理進度：818/1091, 完成ID:10000170
# 對話處理進度：819/1091, 完成ID:10001095
# 對話處理進度：820/1091, 完成ID:10000348
# 對話處理進度：821/1091, 完成ID:10000822
# 對話處理進度：822/1091, 完成ID:10000921
# 對話處理進度：823/1091, 完成ID:10001176
# 對話處理進度：824/1091, 完成ID:10000010
# 對話處理進度：825/1091, 完成ID:10001104
# 對話處理進度：826/1091, 完成ID:10000466
# 對話處理進度：827/1091, 完成ID:10000289
# 對話處理進度：828/1091, 完成ID:10000552
# 對話處理進度：829/1091, 完成ID:10000073
# 對話處理進度：830/1091, 完成ID:10001506
# 對話處理進度：831/1091, 完成ID:10000207
# 對話處理進度：832/1091, 完成ID:10000728
# 對話處理進度：833/1091, 完成ID:10000470
# 對話處理進度：834/1091, 完成ID:10000455
# 對話處理進度：835/1091, 完成ID:10001071
# 對話處理進度：836/1091, 完成ID:10000996
# 對話處理進度：837/1091, 完成ID:10000287
# 對話處理進度：838/1091, 完成ID:10000587
# 對話處理進度：839/1091, 完成ID:10001005
# 對話處理進度：840/1091, 完成ID:10000748
# 對話處理進度：841/1091, 完成ID:10000584
# 對話處理進度：842/1091, 完成ID:10001483
# 對話處理進度：843/1091, 完成ID:10000261
# 對話處理進度：844/1091, 完成ID:10000609
# 對話處理進度：845/1091, 完成ID:10000431
# 對話處理進度：846/1091, 完成ID:10001057
# 對話處理進度：847/1091, 完成ID:10001017
# 對話處理進度：848/1091, 完成ID:10001540
# 對話處理進度：849/1091, 完成ID:10001021
# 對話處理進度：850/1091, 完成ID:10000773
# 對話處理進度：851/1091, 完成ID:10000267
# 對話處理進度：852/1091, 完成ID:10000159
# 對話處理進度：853/1091, 完成ID:10000427
# 對話處理進度：854/1091, 完成ID:10001130
# 對話處理進度：855/1091, 完成ID:10001500
# 對話處理進度：856/1091, 完成ID:10001369
# 對話處理進度：857/1091, 完成ID:10001522
# 對話處理進度：858/1091, 完成ID:10000860
# 對話處理進度：859/1091, 完成ID:10000050
# 對話處理進度：860/1091, 完成ID:10001445
# 對話處理進度：861/1091, 完成ID:10001400
# 對話處理進度：862/1091, 完成ID:10000194
# 對話處理進度：863/1091, 完成ID:10000082
# 對話處理進度：864/1091, 完成ID:10001181
# 對話處理進度：865/1091, 完成ID:10000794
# 對話處理進度：866/1091, 完成ID:10001088
# 對話處理進度：867/1091, 完成ID:10001371
# 對話處理進度：868/1091, 完成ID:10000626
# 對話處理進度：869/1091, 完成ID:10001534
# 對話處理進度：870/1091, 完成ID:10000531
# 對話處理進度：871/1091, 完成ID:10000016
# 對話處理進度：872/1091, 完成ID:10000217
# 對話處理進度：873/1091, 完成ID:10000492
# 對話處理進度：874/1091, 完成ID:10000354
# 對話處理進度：875/1091, 完成ID:10000216
# 對話處理進度：876/1091, 完成ID:10000649
# 對話處理進度：877/1091, 完成ID:10000310
# 對話處理進度：878/1091, 完成ID:10000902
# 對話處理進度：879/1091, 完成ID:10001142
# 對話處理進度：880/1091, 完成ID:10000121
# 對話處理進度：881/1091, 完成ID:10000305
# 對話處理進度：882/1091, 完成ID:10001492
# 對話處理進度：883/1091, 完成ID:10000995
# 對話處理進度：884/1091, 完成ID:10000336
# 對話處理進度：885/1091, 完成ID:10001164
# 對話處理進度：886/1091, 完成ID:10001160
# 對話處理進度：887/1091, 完成ID:10000514
# 對話處理進度：888/1091, 完成ID:10000495
# 對話處理進度：889/1091, 完成ID:10001309
# 對話處理進度：890/1091, 完成ID:10001304
# 對話處理進度：891/1091, 完成ID:10001258
# 對話處理進度：892/1091, 完成ID:10000424
# 對話處理進度：893/1091, 完成ID:10000255
# 對話處理進度：894/1091, 完成ID:10001320
# 對話處理進度：895/1091, 完成ID:10000223
# 對話處理進度：896/1091, 完成ID:10000101
# 對話處理進度：897/1091, 完成ID:10001134
# 對話處理進度：898/1091, 完成ID:10001394
# 對話處理進度：899/1091, 完成ID:10001272
# 對話處理進度：900/1091, 完成ID:10000630
# 對話處理進度：901/1091, 完成ID:10000323
# 對話處理進度：902/1091, 完成ID:10000219
# 對話處理進度：903/1091, 完成ID:10001451
# 對話處理進度：904/1091, 完成ID:10000799
# 對話處理進度：905/1091, 完成ID:10000997
# 對話處理進度：906/1091, 完成ID:10000906
# 對話處理進度：907/1091, 完成ID:10001439
# 對話處理進度：908/1091, 完成ID:10001490
# 對話處理進度：909/1091, 完成ID:10001076
# 對話處理進度：910/1091, 完成ID:10001236
# 對話處理進度：911/1091, 完成ID:10001427
# 對話處理進度：912/1091, 完成ID:10001413
# 對話處理進度：913/1091, 完成ID:10000522
# 對話處理進度：914/1091, 完成ID:10000952
# 對話處理進度：915/1091, 完成ID:10000508
# 對話處理進度：916/1091, 完成ID:10001256
# 對話處理進度：917/1091, 完成ID:10000565
# 對話處理進度：918/1091, 完成ID:10000943
# 對話處理進度：919/1091, 完成ID:10001364
# 對話處理進度：920/1091, 完成ID:10001443
# 對話處理進度：921/1091, 完成ID:10001234
# 對話處理進度：922/1091, 完成ID:10000837
# 對話處理進度：923/1091, 完成ID:10001357
# 對話處理進度：924/1091, 完成ID:10000054
# 對話處理進度：925/1091, 完成ID:10000998
# 對話處理進度：926/1091, 完成ID:10000585
# 對話處理進度：927/1091, 完成ID:10000927
# 對話處理進度：928/1091, 完成ID:10001098
# 對話處理進度：929/1091, 完成ID:10000621
# 對話處理進度：930/1091, 完成ID:10000579
# 對話處理進度：931/1091, 完成ID:10000369
# 對話處理進度：932/1091, 完成ID:10000140
# 對話處理進度：933/1091, 完成ID:10000269
# 對話處理進度：934/1091, 完成ID:10000864
# 對話處理進度：935/1091, 完成ID:10000594
# 對話處理進度：936/1091, 完成ID:10001059
# 對話處理進度：937/1091, 完成ID:10000880
# 對話處理進度：938/1091, 完成ID:10000137
# 對話處理進度：939/1091, 完成ID:10000398
# 對話處理進度：940/1091, 完成ID:10000464
# 對話處理進度：941/1091, 完成ID:10000146
# 對話處理進度：942/1091, 完成ID:10001034
# 對話處理進度：943/1091, 完成ID:10000356
# 對話處理進度：944/1091, 完成ID:10000233
# 對話處理進度：945/1091, 完成ID:10001305
# 對話處理進度：946/1091, 完成ID:10001339
# 對話處理進度：947/1091, 完成ID:10001145
# 對話處理進度：948/1091, 完成ID:10001119
# 對話處理進度：949/1091, 完成ID:10001245
# 對話處理進度：950/1091, 完成ID:10001190
# 對話處理進度：951/1091, 完成ID:10001193
# 對話處理進度：952/1091, 完成ID:10001100
# 對話處理進度：953/1091, 完成ID:10001495
# 對話處理進度：954/1091, 完成ID:10000481
# 對話處理進度：955/1091, 完成ID:10001063
# 對話處理進度：956/1091, 完成ID:10000905
# 對話處理進度：957/1091, 完成ID:10001536
# 對話處理進度：958/1091, 完成ID:10000547
# 對話處理進度：959/1091, 完成ID:10000070
# 對話處理進度：960/1091, 完成ID:YX527AQ5D2
# 對話處理進度：961/1091, 完成ID:10000006
# 對話處理進度：962/1091, 完成ID:10000415
# 對話處理進度：963/1091, 完成ID:10000028
# 對話處理進度：964/1091, 完成ID:10000650
# 對話處理進度：965/1091, 完成ID:10000029
# 對話處理進度：966/1091, 完成ID:10000651
# 對話處理進度：967/1091, 完成ID:10000545
# 對話處理進度：968/1091, 完成ID:10001379
# 對話處理進度：969/1091, 完成ID:10000563
# 對話處理進度：970/1091, 完成ID:10000551
# 對話處理進度：971/1091, 完成ID:10000499
# 對話處理進度：972/1091, 完成ID:10000008
# 對話處理進度：973/1091, 完成ID:10000331
# 對話處理進度：974/1091, 完成ID:10000490
# 對話處理進度：975/1091, 完成ID:10001313
# 對話處理進度：976/1091, 完成ID:10001030
# 對話處理進度：977/1091, 完成ID:10001232
# 對話處理進度：978/1091, 完成ID:10001025
# 對話處理進度：979/1091, 完成ID:10000182
# 對話處理進度：980/1091, 完成ID:10001513
# 對話處理進度：981/1091, 完成ID:10001453
# 對話處理進度：982/1091, 完成ID:10000940
# 對話處理進度：983/1091, 完成ID:10000292
# 對話處理進度：984/1091, 完成ID:10000185
# 對話處理進度：985/1091, 完成ID:10001486
# 對話處理進度：986/1091, 完成ID:10001285
# 對話處理進度：987/1091, 完成ID:10001085
# 對話處理進度：988/1091, 完成ID:10000795
# 對話處理進度：989/1091, 完成ID:10000692
# 對話處理進度：990/1091, 完成ID:10000253
# 對話處理進度：991/1091, 完成ID:10000768
# 對話處理進度：992/1091, 完成ID:10001442
# 對話處理進度：993/1091, 完成ID:10000541
# 對話處理進度：994/1091, 完成ID:10000381
# 對話處理進度：995/1091, 完成ID:10000128
# 對話處理進度：996/1091, 完成ID:10000823
# 對話處理進度：997/1091, 完成ID:10001060
# 對話處理進度：998/1091, 完成ID:10000641
# 對話處理進度：999/1091, 完成ID:10000417
# 對話處理進度：1000/1091, 完成ID:10000721
# 對話處理進度：1001/1091, 完成ID:10000868
# 對話處理進度：1002/1091, 完成ID:10001411
# 對話處理進度：1003/1091, 完成ID:10000408
# 對話處理進度：1004/1091, 完成ID:10000163
# 對話處理進度：1005/1091, 完成ID:10000286
# 對話處理進度：1006/1091, 完成ID:10001208
# 對話處理進度：1007/1091, 完成ID:10000504
# 對話處理進度：1008/1091, 完成ID:10000679
# 對話處理進度：1009/1091, 完成ID:10000882
# 對話處理進度：1010/1091, 完成ID:10000213
# 對話處理進度：1011/1091, 完成ID:10000845
# 對話處理進度：1012/1091, 完成ID:10000951
# 對話處理進度：1013/1091, 完成ID:10001158
# 對話處理進度：1014/1091, 完成ID:10000896
# 對話處理進度：1015/1091, 完成ID:10000202
# 對話處理進度：1016/1091, 完成ID:10000925
# 對話處理進度：1017/1091, 完成ID:10000850
# 對話處理進度：1018/1091, 完成ID:10000141
# 對話處理進度：1019/1091, 完成ID:10000732
# 對話處理進度：1020/1091, 完成ID:10001078
# 對話處理進度：1021/1091, 完成ID:10000114
# 對話處理進度：1022/1091, 完成ID:10000413
# 對話處理進度：1023/1091, 完成ID:10000302
# 對話處理進度：1024/1091, 完成ID:10001292
# 對話處理進度：1025/1091, 完成ID:10000865
# 對話處理進度：1026/1091, 完成ID:10001429
# 對話處理進度：1027/1091, 完成ID:10001300
# 對話處理進度：1028/1091, 完成ID:10000689
# 對話處理進度：1029/1091, 完成ID:10000299
# 對話處理進度：1030/1091, 完成ID:10000835
# 對話處理進度：1031/1091, 完成ID:10000266
# 對話處理進度：1032/1091, 完成ID:10001452
# 對話處理進度：1033/1091, 完成ID:10000684
# 對話處理進度：1034/1091, 完成ID:10000870
# 對話處理進度：1035/1091, 完成ID:10000513
# 對話處理進度：1036/1091, 完成ID:10000105
# 對話處理進度：1037/1091, 完成ID:10001090
# 對話處理進度：1038/1091, 完成ID:10000403
# 對話處理進度：1039/1091, 完成ID:10000699
# 對話處理進度：1040/1091, 完成ID:10000150
# 對話處理進度：1041/1091, 完成ID:10000828
# 對話處理進度：1042/1091, 完成ID:10001229
# 對話處理進度：1043/1091, 完成ID:10000873
# 對話處理進度：1044/1091, 完成ID:10000761
# 對話處理進度：1045/1091, 完成ID:10001359
# 對話處理進度：1046/1091, 完成ID:10000457
# 對話處理進度：1047/1091, 完成ID:10000849
# 對話處理進度：1048/1091, 完成ID:10001518
# 對話處理進度：1049/1091, 完成ID:10000877
# 對話處理進度：1050/1091, 完成ID:10001380
# 對話處理進度：1051/1091, 完成ID:10000674
# 對話處理進度：1052/1091, 完成ID:10000576
# 對話處理進度：1053/1091, 完成ID:10001184
# 對話處理進度：1054/1091, 完成ID:10000187
# 對話處理進度：1055/1091, 完成ID:10001446
# 對話處理進度：1056/1091, 完成ID:10000622
# 對話處理進度：1057/1091, 完成ID:10001084
# 對話處理進度：1058/1091, 完成ID:10000055
# 對話處理進度：1059/1091, 完成ID:10001264
# 對話處理進度：1060/1091, 完成ID:10001061
# 對話處理進度：1061/1091, 完成ID:10001227
# 對話處理進度：1062/1091, 完成ID:10001416
# 對話處理進度：1063/1091, 完成ID:10000821
# 對話處理進度：1064/1091, 完成ID:10000575
# 對話處理進度：1065/1091, 完成ID:10000847
# 對話處理進度：1066/1091, 完成ID:10001489
# 對話處理進度：1067/1091, 完成ID:10001435
# 對話處理進度：1068/1091, 完成ID:10001268
# 對話處理進度：1069/1091, 完成ID:10000442
# 對話處理進度：1070/1091, 完成ID:10000963
# 對話處理進度：1071/1091, 完成ID:10000853
# 對話處理進度：1072/1091, 完成ID:10000449
# 對話處理進度：1073/1091, 完成ID:10000443
# 對話處理進度：1074/1091, 完成ID:10000750
# 對話處理進度：1075/1091, 完成ID:10000733
# 對話處理進度：1076/1091, 完成ID:UTXH0C7LNI
# 對話處理進度：1077/1091, 完成ID:10001295
# 對話處理進度：1078/1091, 完成ID:10001204
# 對話處理進度：1079/1091, 完成ID:10000451
# 對話處理進度：1080/1091, 完成ID:10000297
# 對話處理進度：1081/1091, 完成ID:10000711
# 對話處理進度：1082/1091, 完成ID:10000155
# 對話處理進度：1083/1091, 完成ID:10000720
# 對話處理進度：1084/1091, 完成ID:10000670
# 對話處理進度：1085/1091, 完成ID:10000779
# 對話處理進度：1086/1091, 完成ID:10001230
# 對話處理進度：1087/1091, 完成ID:10000347
# 對話處理進度：1088/1091, 完成ID:10000929
# 對話處理進度：1089/1091, 完成ID:10000494
# 對話處理進度：1090/1091, 完成ID:10000085
# 對話處理進度：1091/1091, 完成ID:10001022

# %%
dialogues_counter
# Out:
# 11

# %%
len(result_list[dialogues_counter-11:dialogues_counter-1])
# Out:
# 10

# %%
#print(result_list[0]["summary"])
# Out:
# ['agent: 客戶經常遇到固網上網斷線問題，經過多次嘗試解決包括重啟路由器、重新設置網絡連接、更改Wi-Fi頻道及檢查設備設置等，仍無法解決問題。建議客戶聯繫技術支持團隊進行進一步排查與協助。', 'customer: 我的固網上網經常斷線，嘗試了重啟路由器、重新設置網絡連接、更改Wi-Fi頻道及檢查設備設置等方法，但問題依舊存在。希望能夠盡快解決這個問題，並在必要時聯繫技術支持團隊。']

# %%
write_json_files(processed_data_folder, result_list)

# %%
import requests

# 定義 API URL
# url = "http://10.144.84.72:7860"
url = "http://localhost:7860"

try:
    # 發送 GET 請求
    response = requests.get(url, timeout=5)
    
    # 檢查回應狀態碼
    if response.status_code == 200:
        print("成功連接到 API:", url)
    else:
        print(f"無法連接到 API，狀態碼: {response.status_code}")
except requests.exceptions.RequestException as e:
    print("連接失敗，錯誤訊息:", e)
# Out:
# 成功連接到 API: http://localhost:7860

# %%
import json

# 假設 fixed_content 是從 API 或其他來源獲得的
try:
    print("原始內容:", fixed_content)
    
    # 修正無效的轉義字符
    fixed_content = fixed_content.replace("\\", "\\\\")
    
    # 嘗試解析 JSON
    parsed_content = json.loads(fixed_content)
    print("解析後的內容:", parsed_content)
except json.JSONDecodeError as e:
    print("JSON 解碼失敗:", e)
# Out:
# 原始內容: [
#     {"type": "agent", "seq": "0", "content": "\\u6211\\u59d3[匿名處理]\\u54e1\\uff0c\\u7de8\\u865f[身份匿名處理]\\u5f88\\u9ad8\\u8208\\u70ba\\u60a8\\u670d\\u52d9\\u4f60\\u597d\\u3002", "starttime": "0.0", "endtime": "6.38"},
#     {"type": "customer", "seq": "1", "content": "\\u4f60\\u597d\\u655d\\u59d3[匿名處理]\\u8cb4\\u59d3\\u600e\\u9ebc\\u7a31\\u547c\\u4f60\\u662f[匿名處理]\\u5148\\u751f\\u60a8\\u597d\\uff0c\\u8acb\\u8aaa", "starttime": "3.38", "endtime": "10.62"},
#     {"type": "agent", "seq": "2", "content": "\\u6211\\u59d3[匿名處理]\\u3002", "starttime": "6.38", "endtime": "8.62"},
#     {"type": "agent", "seq": "3", "content": "\\u55ce\\uff1f\\u5e74\\u8fa6\\u6cd5\\u63a5\\u79d8\\u66f8\\u5ba4\\u7684\\u8aaa\\u660e\\u66f8[匿名處理]\\u5c0f\\u59d0\\u3002", "starttime": "9.88", "endtime": "17.75"},
#     {"type": "customer", "seq": "4", "content": "\\u[匿名處理]\\u5c0f\\u59d0\\u597d\\u5148\\u751f\\uff0c\\u60a8\\u7b49\\u4e00\\u4e0b\\u5594\\u6211\\u5e6b\\u4f60\\u78ba\\u8a8d\\u4e00\\u4e0b\\u5206\\u6a5f\\uff0c\\u8b1d\\u8b1d\\uff01", "starttime": "13.75", "endtime": "19.88"},
#     {"type": "agent", "seq": "5", "content": "\\u60a8\\u597d\\u6211\\u662f\\u5ba2\\u670d\\u4e2d\\u5fc3\\u5c08\\u54e1\\u7de8\\u865f[身份匿名處理]\\u5f88\\u9ad8\\u8208\\u70ba\\u60a8\\u670d\\u52d9\\u4f60\\u597d\\uff01", "starttime": "34.38", "endtime": "42.5"},
#     {"type": "customer", "seq": "6", "content": "\\u60a8\\u597d\\u662f\\u5df2\\u8ddf\\u4f60\\u78ba\\u5b9a\\u4e00\\u4e0b\\uff0c\\u6709\\u4e00\\u500b\\u4eba\\u8981\\u6c42\\u8981\\u6307\\u5b9a\\u8f49\\u66f8\\u79d8\\u66f8\\u5ba4[匿名處理]\\u5c0f\\u59d0\\u3002\\u6211\\u770b\\u4ed6\\u4eca\\u5929\\u524d\\u9762\\u6253\\u4e86\\u5169\\u901a\\u9032\\u4f86\\u4e86\\u632a\\uff0c\\u6211\\u8981\\u63a5\\u54ea\\u88e1\\u554a\\u3002", "starttime": "40.88", "endtime": "53.38"},
#     {"type": "agent", "seq": "7", "content": "\\u[匿名處理]\\u5c0f\\u59d0\\u5c31\\u662f\\u55c5\\u89ba\\u4e03\\u4e8c\\u516d\\u516d\\uff0c\\u5c0d\\u5c31\\u4e0d\\u8981\\u8b1b\\u5c31\\u9019\\u6bb5\\u4e00\\u4e8c\\u516d\\u516d\\u3002", "starttime": "48.5", "endtime": "60.0"},
#     {"type": "customer", "seq": "8", "content": "\\u4e00\\u4e8c\\u516d\\u516d\\u597d\\uff0c\\u8b1d\\u8b1d\\u5594\\u5594OK\\u597d\\u8b1d\\u8b1d\\uff01", "starttime": "54.88", "endtime": "59.75"},
#     {"type": "agent", "seq": "9", "content": "\\u5594", "starttime": "60.0", "endtime": "61.38"},
#     {"type": "agent", "seq": "10", "content": "\\u6216", "starttime": "64.88", "endtime": "67.5"},
#     {"type": "customer", "seq": "11", "content": "\\u55ef\\u8b1d\\u5c0f\\u59d0\\u4f60\\u597d\\uff0c\\u6211\\u662f\\u4ee5\\u4e0d\\u597d\\u610f\\u601d\\u7dda\\u4e0a\\u6709\\u500b[匿名處理]\\u5148\\u751f\\u8aaa\\uff0c\\u4ed6\\u8981\\u6307\\u5b9a\\u627e\\u60a8\\u6709\\u8ddf\\u4f60\\u901a\\u8a71\\u904e\\u90a3\\u80fd\\u5426\\uff0c\\u5148\\u50b3\\u7d66\\u60a8\\u502a\\u3002", "starttime": "65.75", "endtime": "75.88"},
#     {"type": "agent", "seq": "12", "content": "\\u597d\\u77e5\\u9053\\u4e86", "starttime": "75.62", "endtime": "77.88"},
#     {"type": "customer", "seq": "13", "content": "\\u597d\\uff0c\\u8b1d\\u8b1d\\uff01", "starttime": "76.25", "endtime": "79.0"},
#     {"type": "customer", "seq": "14", "content": "\\u60a8\\u597d\\u655d\\u59d3[匿名處理]\\u8acb\\u554f\\u600e\\u9ebc\\u7a31\\u547c\\u60a8\\uff01", "starttime": "78.88", "endtime": "83.0"},
#     {"type": "agent", "seq": "15", "content": "\\u6b38[匿名處理]\\u5c0f\\u59d0\\uff0c\\u4f60\\u597d\\uff0c[匿名處理]\\u5148\\u751f\\u8981\\u600e\\u6a23", "starttime": "82.62", "endtime": "87.38"},
#     {"type": "customer", "seq": "16", "content": "\\u6b38\\u5148\\u751f\\u60a8\\u597d\\u5443\\u60a8\\u662f\\u7db2\\u9801", "starttime": "84.12", "endtime": "90.0"},
#     {"type": "agent", "seq": "17", "content": "\\u563f\\uff01", "starttime": "87.75", "endtime": "89.12"},
#     {"type": "customer", "seq": "18", "content": "\\u90a3\\u6211\\u5148\\u751f\\u662f\\u4e0d\\u662f\\u662f\\u60a8\\u597d\\uff0c\\u90a3\\u60a8\\u7684\\u6848\\u5b50\\u6211\\u6709\\u65e9\\u4e0a\\u9084\\u770b\\u4e86\\u4e00\\u4e0b\\u6211\\u5011\\u4ee5\\u524d\\u6709\\u79fb\\u7d66\\u5c08\\u696d\\u91ab\\u5e2b\\u5be9\\u67e5\\u4e86\\u3002", "starttime": "90.0", "endtime": "102.0"},
#     {"type": "agent", "seq": "19", "content": "\\u5c0d\\u5c0d\\u5c0d\\u5c0d\\u5c0d\\u3002", "starttime": "90.62", "endtime": "93.0"},
#     {"type": "agent", "seq": "20", "content": "\\u563f\\u563f", "starttime": "97.62", "endtime": "99.25"},
#     {"type": "agent", "seq": "21", "content": "\\u6b38\\u4f60\\u5011\\u4e09\\u500b\\u79ae\\u62dc\\uff0c\\u4e0d\\u662f\\u5c31\\u5df2\\u7d93\\u79fb\\u9001\\u5c08\\u696d\\u91ab\\u5e2b\\u5be9\\u67e5\\u4e86\\u55ce\\uff1f", "starttime": "102.0", "endtime": "109.38"},
#     {"type": "customer", "seq": "22", "content": "\\u5c0d", "starttime": "102.75", "endtime": "104.5"},
#     {"type": "customer", "seq": "23", "content": "\\u6c92\\u6709\\u516b\\u6708\\u56db\\u865f\\u7684\\u6642\\u5019\\uff0c\\u6211\\u5011\\u4ee5\\u7d66\\u5c08\\u696d\\u91ab\\u5e2b\\u5be9\\u67e5\\u5e6b\\u4ed6\\u6708\\u56db\\u865f\\u5c0d\\u3002", "starttime": "107.88", "endtime": "117.5"},
#     {"type": "agent", "seq": "24", "content": "\\u516b\\u6708\\u56db\\u865f", "starttime": "114.5", "endtime": "116.62"},
#     {"type": "agent", "seq": "25", "content": "\\u554a\\uff0c\\u4eca\\u5929\\u5e7e\\u865f", "starttime": "117.62", "endtime": "120.0"},
#     {"type": "customer", "seq": "26", "content": "\\u5594\\u7b49\\u4e00\\u4e0b\\u4e0d\\u662f\\u516b\\u6708", "starttime": "117.88", "endtime": "120.0"},
#     {"type": "customer", "seq": "27", "content": "\\u56db\\u865f\\u7b49\\u6211\\u4e00\\u4e0b\\u6211\\u628a\\u4f60\\u7684\\u6a94\\u6848\\u8df3\\u51fa\\u4f86\\u56e0\\u70ba\\u6211\\u5728\\u770b\\u5225\\u7684\\u6771\\u897f\\u5c0d\\u4e0d\\u8d77\\u6211\\u770b\\u4e00\\u4e0b\\u3002", "starttime": "120.0", "endtime": "127.62"},
#     {"type": "customer", "seq": "28", "content": "\\u662f", "starttime": "127.75", "endtime": "129.88"},
#     {"type": "customer", "seq": "29", "content": "\\u5c0d\\u516b\\u6708\\u56db\\u865f\\u5df2\\u7d66\\u5c08\\u696d\\u91ab\\u5e2b\\uff0c\\u6211\\u770b\\u4ed6\\u90a3\\u500b\\u5c08\\u696d\\u91ab\\u5e2b\\u7684\\u90e8\\u5206\\u56de\\u4f86\\u4e86\\u6c92\\u6709\\u6211\\u9084\\u6c92\\u6709\\u3002", "starttime": "133.62", "endtime": "145.5"},
#     {"type": "agent", "seq": "30", "content": "\\u4e5d\\u865f\\u9700\\u8981\\u4e5f\\u4e5f\\u4eca\\u5929\\u75fe\\uff0c\\u4f60\\u8aaa\\u6700\\u6162\\u6642\\u9593\\u5462\\uff1f", "starttime": "142.75", "endtime": "150.0"},
#     {"type": "customer", "seq": "31", "content": "\\u6211\\u77e5\\u9053\\u61c9\\u8a72\\u662f\\u3002", "starttime": "147.25", "endtime": "150.0"},
#     {"type": "customer", "seq": "32", "content": "\\u8aaa\\u91ab\\u5e2b\\u7684\\u90e8\\u5206\\u6848\\u5b50\\u9084\\u6c92\\u6709\\u56de\\u4f86\\u7d66\\u6211\\u5011\\uff0c\\u90a3\\u60a8\\u7684\\u6848\\u5b50\\uff0c\\u6211\\u9084\\u662f\\u6703\\u7559\\u610f\\u5230\\u76ee\\u524d\\u70ba\\u6b62\\u91ab\\u5e2b\\u6211\\u5011\\u662f\\u516b\\u6708\\u56db\\u865f\\u9001\\u91ab\\u5e2b\\u5c08\\u696d\\u4e00\\u3002", "starttime": "150.0", "endtime": "164.15"},
#     {"type": "customer", "seq": "33", "content": "\\u9084\\u6c92\\u6709\\u56de\\u8986\\u7d66\\u52de\\u4fdd\\u5c40\\uff0c\\u90a3\\u5982\\u679c\\u4ed6\\u4e00\\u65e6\\u56de\\u8986\\u7d66\\u52de\\u4fdd\\u5c40\\uff0c\\u6211\\u5c31\\u99ac\\u4e0a\\u8acb\\u4ed6\\u5011\\u89e3\\u6848\\uff0c\\u5982\\u679c\\u6c92\\u6709\\u5176\\u4ed6\\u7591\\u7fa9\\uff0c\\u6211\\u5c31\\u8acb\\u4ed6\\u5011\\u59d0\\u5f88\\u597d\\u4e0d\\u597d\\u3002", "starttime": "165.25", "endtime": "177.12"},
#     {"type": "agent", "seq": "34", "content": "\\u9019\\u6a23\\u5594", "starttime": "176.75", "endtime": "178.62"},
#     {"type": "customer", "seq": "35", "content": "\\u662f\\u662f\\u662f", "starttime": "177.62", "endtime": "180.0"},
#     {"type": "agent", "seq": "36", "content": "\\u6b38\\uff01", "starttime": "178.5", "endtime": "180.0"},
#     {"type": "agent", "seq": "37", "content": "\\u518d\\u9ebb\\u7169\\u4f60\\u4e00\\u4e0b\\u751f\\u7684\\u8eab\\u5206\\u3002", "starttime": "180.0", "endtime": "183.25"},
#     {"type": "customer", "seq": "38", "content": "\\u6703\\u8ac7\\u9084\\u6709\\u6211\\u77e5\\u9053\\u6211\\u77e5\\u9053\\uff0c\\u56e0\\u70ba\\u6211\\u8981\\u5148\\u60a8\\u6709\\u63d0\\u5230\\u8aaa\\u5443\\uff0c\\u78ba\\u5be6\\u4ed6\\u9084\\u6709\\u554f\\u984c\\uff0c\\u6211\\u667a\\u5546\\u671f\\u9593\\u78ba\\u5be6\\u7e3d\\u662f\\u6703\\u6709\\u4e00\\u4e9b\\u7d93\\u6fdf\\u4e0a\\u7684\\u9700\\u8981\\u3002", "starttime": "180.25", "endtime": "194.75"},
#     {"type": "agent", "seq": "39", "content": "\\u5c0d", "starttime": "186.0", "endtime": "187.5"},
#     {"type": "agent", "seq": "40", "content": "\\u53ef\\u4ee5\\u554a\\uff01", "starttime": "194.25", "endtime": "196.75"},
#     {"type": "customer", "seq": "41", "content": "\\u90a3\\u6211\\u65e9\\u4e0a\\u6211\\u5c31\\u6709\\u518d\\u53bb\\u8ffd\\u8e64\\u4e00\\u4e0b\\u6848\\u5b50\\uff0c\\u53ef\\u662f\\u56e0\\u70ba\\u5443\\uff0c\\u4ed6\\u7684\\u91ab\\u5e2b\\u5be9\\u67e5\\u7684\\u90e8\\u5206\\u9084\\u6c92\\u6709\\u56de\\u4f86\\uff0c\\u6211\\u96d6\\u4ed6\\u5011\\u5c31\\u6c92\\u6709\\u7528\\uff0c\\u90a3\\u5fc5\\u9808\\u8981\\u7b49\\u
# JSON 解碼失敗: Unterminated string starting at: line 43 column 50 (char 10032)
